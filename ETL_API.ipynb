# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
from tqdm import tqdm_notebook as tqdm
from bs4 import BeautifulSoup as bs
from splinter import Browser

# %%
# Windows Users - Executable Path
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# # Use Pandas to scrape the table containing stocks data.
# url_stock = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
# # browser.visit(url_stock)
# stock_table = pd.read_html(url_stock)
# stock_table
# print(stock_table)
# Out:
# [    Symbol                         Security SEC filings  \
# 0      MMM                       3M Company     reports
# 1      ABT              Abbott Laboratories     reports
# 2     ABBV                      AbbVie Inc.     reports
# 3     ABMD                      ABIOMED Inc     reports
# 4      ACN                    Accenture plc     reports
# 5     ATVI              Activision Blizzard     reports
# 6     ADBE                Adobe Systems Inc     reports
# 7      AMD       Advanced Micro Devices Inc     reports
# 8      AAP               Advance Auto Parts     reports
# 9      AES                         AES Corp     reports
# 10     AMG    Affiliated Managers Group Inc     reports
# 11     AFL                        AFLAC Inc     reports
# 12       A         Agilent Technologies Inc     reports
# 13     APD     Air Products & Chemicals Inc     reports
# 14    AKAM          Akamai Technologies Inc     reports
# 15     ALK             Alaska Air Group Inc     reports
# 16     ALB                   Albemarle Corp     reports
# 17     ARE  Alexandria Real Estate Equities     reports
# 18    ALXN          Alexion Pharmaceuticals     reports
# 19    ALGN                 Align Technology     reports
# 20    ALLE                         Allegion     reports
# 21     AGN                    Allergan, Plc     reports
# 22     ADS            Alliance Data Systems     reports
# 23     LNT              Alliant Energy Corp     reports
# 24     ALL                    Allstate Corp     reports
# 25   GOOGL             Alphabet Inc Class A     reports
# 26    GOOG             Alphabet Inc Class C     reports
# 27      MO                 Altria Group Inc     reports
# 28    AMZN                  Amazon.com Inc.     reports
# 29    AMCR                        Amcor plc     reports
# ..     ...                              ...         ...
# 475   VIAB                      Viacom Inc.     reports
# 476      V                        Visa Inc.     reports
# 477    VNO             Vornado Realty Trust     reports
# 478    VMC                 Vulcan Materials     reports
# 479    WAB               Wabtec Corporation     reports
# 480    WMT                          Walmart     reports
# 481    WBA         Walgreens Boots Alliance     reports
# 482    DIS          The Walt Disney Company     reports
# 483     WM            Waste Management Inc.     reports
# 484    WAT               Waters Corporation     reports
# 485    WEC             Wec Energy Group Inc     reports
# 486    WCG                         WellCare     reports
# 487    WFC                      Wells Fargo     reports
# 488   WELL                   Welltower Inc.     reports
# 489    WDC                  Western Digital     reports
# 490     WU                 Western Union Co     reports
# 491    WRK                         WestRock     reports
# 492     WY                     Weyerhaeuser     reports
# 493    WHR                  Whirlpool Corp.     reports
# 494    WMB                    Williams Cos.     reports
# 495   WLTW             Willis Towers Watson     reports
# 496   WYNN                 Wynn Resorts Ltd     reports
# 497    XEL                  Xcel Energy Inc     reports
# 498    XRX                            Xerox     reports
# 499   XLNX                           Xilinx     reports
# 500    XYL                       Xylem Inc.     reports
# 501    YUM                  Yum! Brands Inc     reports
# 502    ZBH           Zimmer Biomet Holdings     reports
# 503   ZION                    Zions Bancorp     reports
# 504    ZTS                           Zoetis     reports
#
#                 GICS Sector                             GICS Sub Industry  \
# 0               Industrials                      Industrial Conglomerates
# 1               Health Care                         Health Care Equipment
# 2               Health Care                               Pharmaceuticals
# 3               Health Care                         Health Care Equipment
# 4    Information Technology                IT Consulting & Other Services
# 5    Communication Services                Interactive Home Entertainment
# 6    Information Technology                          Application Software
# 7    Information Technology                                Semiconductors
# 8    Consumer Discretionary                             Automotive Retail
# 9                 Utilities  Independent Power Producers & Energy Traders
# 10               Financials              Asset Management & Custody Banks
# 11               Financials                       Life & Health Insurance
# 12              Health Care                         Health Care Equipment
# 13                Materials                              Industrial Gases
# 14   Information Technology            Internet Services & Infrastructure
# 15              Industrials                                      Airlines
# 16                Materials                           Specialty Chemicals
# 17              Real Estate                                  Office REITs
# 18              Health Care                                 Biotechnology
# 19              Health Care                          Health Care Supplies
# 20              Industrials                             Building Products
# 21              Health Care                               Pharmaceuticals
# 22   Information Technology         Data Processing & Outsourced Services
# 23                Utilities                            Electric Utilities
# 24               Financials                 Property & Casualty Insurance
# 25   Communication Services                  Interactive Media & Services
# 26   Communication Services                  Interactive Media & Services
# 27         Consumer Staples                                       Tobacco
# 28   Consumer Discretionary            Internet & Direct Marketing Retail
# 29                Materials                               Paper Packaging
# ..                      ...                                           ...
# 475  Communication Services                        Movies & Entertainment
# 476  Information Technology         Data Processing & Outsourced Services
# 477             Real Estate                                  Office REITs
# 478               Materials                        Construction Materials
# 479             Industrials         Construction Machinery & Heavy Trucks
# 480        Consumer Staples                  Hypermarkets & Super Centers
# 481        Consumer Staples                                   Drug Retail
# 482  Communication Services                        Movies & Entertainment
# 483             Industrials           Environmental & Facilities Services
# 484             Health Care                      Health Care Distributors
# 485               Utilities                            Electric Utilities
# 486             Health Care                           Managed Health Care
# 487              Financials                             Diversified Banks
# 488             Real Estate                             Health Care REITs
# 489  Information Technology    Technology Hardware, Storage & Peripherals
# 490  Information Technology         Data Processing & Outsourced Services
# 491               Materials                               Paper Packaging
# 492             Real Estate                             Specialized REITs
# 493  Consumer Discretionary                          Household Appliances
# 494                  Energy            Oil & Gas Storage & Transportation
# 495              Financials                             Insurance Brokers
# 496  Consumer Discretionary                              Casinos & Gaming
# 497               Utilities                               Multi-Utilities
# 498  Information Technology    Technology Hardware, Storage & Peripherals
# 499  Information Technology                                Semiconductors
# 500             Industrials                          Industrial Machinery
# 501  Consumer Discretionary                                   Restaurants
# 502             Health Care                         Health Care Equipment
# 503              Financials                                Regional Banks
# 504             Health Care                               Pharmaceuticals
#
#                 Headquarters Location Date first added      CIK      Founded
# 0                 St. Paul, Minnesota              NaN    66740         1902
# 1             North Chicago, Illinois       1964-03-31     1800         1888
# 2             North Chicago, Illinois       2012-12-31  1551152  2013 (1888)
# 3              Danvers, Massachusetts       2018-05-31   815094         1981
# 4                     Dublin, Ireland       2011-07-06  1467373         1989
# 5            Santa Monica, California       2015-08-31   718877         2008
# 6                San Jose, California       1997-05-05   796343         1982
# 7               Sunnyvale, California       2017-03-20     2488         1969
# 8             Raleigh, North Carolina       2015-07-09  1158449         1932
# 9                 Arlington, Virginia       1998-10-02   874761         1981
# 10           West Palm Beach, Florida       2014-07-01  1004434         1993
# 11                  Columbus, Georgia       1999-05-28     4977         1955
# 12            Santa Clara, California       2000-06-05  1090872         1999
# 13            Allentown, Pennsylvania       1985-04-30     2969         1940
# 14           Cambridge, Massachusetts       2007-07-12  1086222         1998
# 15                Seattle, Washington       2016-05-13   766421         1985
# 16          Charlotte, North Carolina       2016-07-01   915913         1994
# 17               Pasadena, California       2017-03-20  1035443         1994
# 18              Boston, Massachusetts       2012-05-25   899866         1992
# 19               San Jose, California       2017-06-19  1097149         1997
# 20                    Dublin, Ireland       2013-12-02  1579241         1908
# 21                    Dublin, Ireland       1999-04-12  1578845         1983
# 22                       Plano, Texas       2013-12-23  1101215         1996
# 23                 Madison, Wisconsin       2016-07-01   352541         1917
# 24      Northfield Township, Illinois       1995-07-13   899051         1931
# 25          Mountain View, California       2014-04-03  1652044         1998
# 26          Mountain View, California       2006-04-03  1652044         1998
# 27                 Richmond, Virginia              NaN   764180         1985
# 28                Seattle, Washington       2005-11-18  1018724         1994
# 29   Warmley, Bristol, United Kingdom       2019-06-07  1748790          NaN
# ..                                ...              ...      ...          ...
# 475                New York, New York              NaN  1339947          NaN
# 476         San Francisco, California       2009-12-21  1403161          NaN
# 477                New York, New York              NaN   899689          NaN
# 478               Birmingham, Alabama       1999-06-30  1396009          NaN
# 479          Wilmerding, Pennsylvania       2019-02-27   943452          NaN
# 480             Bentonville, Arkansas       1982-08-31   104169          NaN
# 481               Deerfield, Illinois       1979-12-31  1618921          NaN
# 482               Burbank, California       1976-06-30  1001039          NaN
# 483                    Houston, Texas              NaN   823768         1968
# 484            Milford, Massachusetts              NaN  1000697         1958
# 485              Milwaukee, Wisconsin       2008-10-31   783325          NaN
# 486                    Tampa, Florida             1985  1279363          NaN
# 487         San Francisco, California       1976-06-30    72971          NaN
# 488                      Toledo, Ohio       2009-01-30   766704          NaN
# 489                Irvine, California       2009-07-01   106040          NaN
# 490               Englewood, Colorado              NaN  1365135         1851
# 491                Richmond, Virginia              NaN  1636023          NaN
# 492           Federal Way, Washington              NaN   106535          NaN
# 493           Benton Harbor, Michigan              NaN   106640         1911
# 494                   Tulsa, Oklahoma       1975-03-31   107263          NaN
# 495            London, United Kingdom       2016-01-05  1140536          NaN
# 496                  Paradise, Nevada       2008-11-14  1174922          NaN
# 497            Minneapolis, Minnesota              NaN    72903         1909
# 498              Norwalk, Connecticut              NaN   108772         1906
# 499              San Jose, California       1999-11-08   743988          NaN
# 500            White Plains, New York       2011-11-01  1524472          NaN
# 501              Louisville, Kentucky       1997-10-06  1041061          NaN
# 502                   Warsaw, Indiana       2001-08-07  1136869          NaN
# 503              Salt Lake City, Utah       2001-06-22   109380          NaN
# 504          Florham Park, New Jersey       2013-06-21  1555280          NaN
#
# [505 rows x 9 columns],                    Date  Added                                 Removed  \
#                    Date Ticker                        Security  Ticker
# 0        August 9, 2019   LDOS                 Leidos Holdings     APC
# 1        August 9, 2019    IEX                IDEX Corporation      FL
# 2         July 15, 2019   TMUS                     T-Mobile US     RHT
# 3          July 1, 2019   MKTX                     MarketAxess     LLL
# 4          June 7, 2019    BMS                    Bemis Co Inc     MAT
# 5          June 3, 2019   CTVA                         Corteva     FLR
# 6         April 2, 2019    DOW                        Dow Inc.     BHF
# 7     February 27, 2019    WAB              Wabtec Corporation      GT
# 8     February 15, 2019    ATO               Atmos Energy Corp     NFX
# 9      January 18, 2019    TFX                        Teleflex     PCG
# 10      January 2, 2019    FRC             First Republic Bank     SCG
# 11    December 24, 2018     CE                        Celanese    ESRX
# 12     December 3, 2018     LW        Lamb Weston Holdings Inc     COL
# 13     December 3, 2018   MXIM   Maxim Integrated Products Inc     AET
# 14     December 3, 2018   FANG              Diamondback Energy    SRCL
# 15    November 13, 2018   JKHY         Jack Henry & Associates     EQT
# 16     November 6, 2018   KEYS           Keysight Technologies      CA
# 17     October 11, 2018   FTNT                        Fortinet    EVHC
# 18      October 1, 2018    ROL                    Rollins Inc.    ANDV
# 19   September 14, 2018    WCG                        WellCare      XL
# 20      August 28, 2018   ANET                 Arista Networks     GGP
# 21         July 2, 2018   CPRT                          Copart     DPS
# 22        June 20, 2018    FLT           FleetCor Technologies     TWX
# 23        June 18, 2018     BR  Broadridge Financial Solutions     RRC
# 24        June 18, 2018    HFC                   HollyFrontier     AYI
# 25         June 7, 2018   TWTR                         Twitter     MON
# 26         June 5, 2018   EVRG                          Evergy    NAVI
# 27         May 31, 2018   ABMD                         Abiomed     WYN
# 28        April 4, 2018   MSCI                            MSCI    CSRA
# 29       March 19, 2018   TTWO            Take-Two Interactive     SIG
# ..                  ...    ...                             ...     ...
# 186      March 31, 2011     EW            Edwards Lifesciences       Q
# 187   February 28, 2011    COV                    Covidien Plc     MFE
# 188   February 25, 2011    JOY                 Joy Global Inc.     AYE
# 189   December 17, 2010    CVC       Cablevision Systems Corp.      KG
# 190   December 17, 2010   FFIV                F5 Networks Inc.      EK
# 191   December 17, 2010   NFLX                    Netflix Inc.     ODP
# 192   December 17, 2010    NFX            Newfield Exploration     NYT
# 193     August 26, 2010    TYC         Tyco International Ltd.     SII
# 194       July 14, 2010     CB                   Chubb Limited     MIL
# 195       June 30, 2010    QEP                   QEP Resources     STR
# 196       June 28, 2010    KMX                    CarMax, Inc.     XTO
# 197      April 29, 2010   CERN                    Cerner Corp.     BJS
# 198   February 26, 2010     HP               Helmerich & Payne      RX
# 199    November 3, 2009   PCLN                   Priceline.com     SGP
# 200  September 28, 2009    ARG                      Airgas Inc     CBE
# 201       March 3, 2009    HRL                    Hormel Foods    ACAS
# 202       March 3, 2009    VTR                     Ventas Inc.     JNY
# 203       June 10, 2008     LO                  Lorillard Inc.     ABK
# 204   December 20, 2007    RRC                 Range Resources     TRB
# 205   December 13, 2007    GME                        GameStop      DJ
# 206    October 25, 2007    JEC        Jacobs Engineering Group      AV
# 207     August 24, 2007    LUK               Leucadia National     KSE
# 208      March 30, 2007    KFT                     Kraft Foods     TSG
# 209    January 10, 2007    AVB     AvalonBay Communities, Inc.     SBL
# 210        July 1, 2005    STZ            Constellation Brands     GLK
# 211  September 25, 2003   ESRX                 Express Scripts    QTRN
# 212    December 5, 2000   INTU                          Intuit      BS
# 213    December 5, 2000    SBL             Symbol Technologies      OI
# 214    December 5, 2000    AYE                Allegheny Energy     GRA
# 215    December 5, 2000    ABK                 Ambac Financial     CCK
#
#                                          \
#                                Security
# 0                    Anadarko Petroleum
# 1                           Foot Locker
# 2                               Red Hat
# 3                       L3 Technologies
# 4                            Mattel Inc
# 5                     Fluor Corporation
# 6                 Brighthouse Financial
# 7    The Goodyear Tire & Rubber Company
# 8                  Newfield Exploration
# 9                             PG&E Corp
# 10                                SCANA
# 11                      Express Scripts
# 12                     Rockwell Collins
# 13                            Aetna Inc
# 14                           Stericycle
# 15                             EQT Corp
# 16                              CA Inc.
# 17                  Envision Healthcare
# 18                             Andeavor
# 19                             XL Group
# 20                             GGP Inc.
# 21              Dr Pepper Snapple Group
# 22                          Time Warner
# 23                      Range Resources
# 24                        Acuity Brands
# 25                             Monsanto
# 26                         Navient Corp
# 27                    Wyndham Worldwide
# 28                            CSRA Inc.
# 29                      Signet Jewelers
# ..                                  ...
# 186                Qwest Communications
# 187                         McAfee Inc.
# 188               Allegheny Energy Inc.
# 189           King Pharmaceuticals Inc.
# 190                   Eastman Kodak Co.
# 191                   Office Depot Inc.
# 192              The New York Times Co.
# 193            Smith International Inc.
# 194                      Millipore Inc.
# 195                       Questar Corp.
# 196                     XTO Energy Inc.
# 197                 BJ Services Company
# 198                          IMS Health
# 199               Schering-Plough Corp.
# 200              Cooper Industries Ltd.
# 201                    American Capital
# 202                 Jones Apparel Group
# 203                     Ambac Financial
# 204                         Tribune Co.
# 205                           Dow Jones
# 206                          Avaya Inc.
# 207                             KeySpan
# 208                      Sabre Holdings
# 209                 Symbol Technologies
# 210                Great Lakes Chemical
# 211             Quintiles Transnational
# 212                     Bethlehem Steel
# 213                      Owens-Illinois
# 214                          W.R. Grace
# 215                      Crown Holdings
#
#                                                 Reason
#                                                 Reason
# 0    S&P 500 & 100 constituent Occidental Petroleum...
# 1          Foot Locker moved to the S&P MidCap 400.[7]
# 2    S&P 500 & 100 constituent IBM acquired Red Hat...
# 3                L3 purchased by Harris Corporation[9]
# 4    Bemis merges with Amcor; subsequently renamed ...
# 5    CTVA spun off from DWDP (which then changed sy...
# 6                           DOW spun off from DWDP[12]
# 7          WAB acquired GE transportation business[13]
# 8                                 ECA acquired NFX[14]
# 9                         PCG filed for bankruptcy[15]
# 10      Dominion Energy acquired SCANA Corporation[16]
# 11   S&P 500 constituent Cigna (NYSE: CI) acquired ...
# 12                                UTX acquired COL[18]
# 13                              CVS acquired Aetna[18]
# 14                    Market Capitalization change[18]
# 15                               EQT spun off ETRN[19]
# 16                   CA acquired by Broadcom Inc..[20]
# 17       EVHC acquired by Kohlberg Kravis Roberts.[21]
# 18            ANDV acquired by Marathon Petroleum.[22]
# 19                             XL acquired by AXA.[23]
# 20   GGP acquired by Brookfield Property Partners.[24]
# 21          DPS acquired by Keurig Green Mountain.[25]
# 22                      AT&T acquired Time Warner.[26]
# 23                       Capitalization rebalance.[27]
# 24                       Capitalization rebalance.[27]
# 25                        Bayer acquired Monsanto.[28]
# 26   Westar Energy (NYSE: WR) acquired Great Plains...
# 27   Wyndham Worldwide spun off Wyndham Hotels & Re...
# 28   S&P 500 constituent General Dynamics Corp. (NY...
# 29                  Market capitalization changes.[32]
# ..                                                 ...
# 186                       Acquired by CenturyLink[159]
# 187                Acquired by Intel Corp. (INTC)[160]
# 188                Acquired by First Energy (FE).[161]
# 189                Acquired by Pfizer Inc. (PFE).[162]
# 190                           Market Cap changes.[162]
# 191                           Market Cap changes.[162]
# 192                           Market Cap changes.[162]
# 193           Acquired by Schlumberger Ltd. (SLB)[163]
# 194                Acquired by Merck KGaA (MKGAY)[164]
# 195  Company split. QEP retained, but ticker change...
# 196             Acquired by ExxonMobil Inc. (XOM)[166]
# 197           Acquired by Baker Hughes Inc. (BHI)[167]
# 198                                 Taken private[168]
# 199                 Acquired by Merck & Co. (MRK)[169]
# 200                     Redomesticated to Ireland[170]
# 201                     Capitalization rebalance.[171]
# 202                     Capitalization rebalance.[171]
# 203                          Market Value Decline[172]
# 204                                 Taken private[173]
# 205                        Acquired by News Corp.[174]
# 206                                 Taken private[175]
# 207                 Acquired by National Grid plc[176]
# 208                                 Taken Private[177]
# 209                          Acquired by Motorola[178]
# 210                    Acquired by Crompton Corp.[179]
# 211                                 Taken private[180]
# 212                           Market Cap changes.[181]
# 213                           Market Cap changes.[181]
# 214                           Market Cap changes.[181]
# 215                           Market Cap changes.[181]
# [216 rows x 6 columns]]

# %%
# type(stock_table)
# stock_table_df = stock_table[0]
# stock_table_df.to_csv("stocks_data/fortune500table.csv", index=False, encoding='utf8')
# stock_table_df.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota              NaN
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
# symbols_list = stock_table_df["Symbol"].values.tolist()
# symbols_list
# Out:
# ['MMM',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADBE',
#  'AMD',
#  'AAP',
#  'AES',
#  'AMG',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALXN',
#  'ALGN',
#  'ALLE',
#  'AGN',
#  'ADS',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'AOS',
#  'APA',
#  'AIV',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ADM',
#  'ARNC',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'ATO',
#  'T',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BHGE',
#  'BLL',
#  'BAC',
#  'BK',
#  'BAX',
#  'BBT',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIIB',
#  'BLK',
#  'HRB',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BF.B',
#  'CHRW',
#  'COG',
#  'CDNS',
#  'CPB',
#  'COF',
#  'CPRI',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CBS',
#  'CE',
#  'CELG',
#  'CNC',
#  'CNP',
#  'CTL',
#  'CERN',
#  'CF',
#  'SCHW',
#  'CHTR',
#  'CVX',
#  'CMG',
#  'CB',
#  'CHD',
#  'CI',
#  'XEC',
#  'CINF',
#  'CTAS',
#  'CSCO',
#  'C',
#  'CFG',
#  'CTXS',
#  'CLX',
#  'CME',
#  'CMS',
#  'KO',
#  'CTSH',
#  'CL',
#  'CMCSA',
#  'CMA',
#  'CAG',
#  'CXO',
#  'COP',
#  'ED',
#  'STZ',
#  'COO',
#  'CPRT',
#  'GLW',
#  'CTVA',
#  'COST',
#  'COTY',
#  'CCI',
#  'CSX',
#  'CMI',
#  'CVS',
#  'DHI',
#  'DHR',
#  'DRI',
#  'DVA',
#  'DE',
#  'DAL',
#  'XRAY',
#  'DVN',
#  'FANG',
#  'DLR',
#  'DFS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DG',
#  'DLTR',
#  'D',
#  'DOV',
#  'DOW',
#  'DTE',
#  'DUK',
#  'DRE',
#  'DD',
#  'DXC',
#  'ETFC',
#  'EMN',
#  'ETN',
#  'EBAY',
#  'ECL',
#  'EIX',
#  'EW',
#  'EA',
#  'EMR',
#  'ETR',
#  'EOG',
#  'EFX',
#  'EQIX',
#  'EQR',
#  'ESS',
#  'EL',
#  'EVRG',
#  'ES',
#  'RE',
#  'EXC',
#  'EXPE',
#  'EXPD',
#  'EXR',
#  'XOM',
#  'FFIV',
#  'FB',
#  'FAST',
#  'FRT',
#  'FDX',
#  'FIS',
#  'FITB',
#  'FE',
#  'FRC',
#  'FISV',
#  'FLT',
#  'FLIR',
#  'FLS',
#  'FMC',
#  'F',
#  'FTNT',
#  'FTV',
#  'FBHS',
#  'FOXA',
#  'FOX',
#  'BEN',
#  'FCX',
#  'GPS',
#  'GRMN',
#  'IT',
#  'GD',
#  'GE',
#  'GIS',
#  'GM',
#  'GPC',
#  'GILD',
#  'GL',
#  'GPN',
#  'GS',
#  'GWW',
#  'HAL',
#  'HBI',
#  'HOG',
#  'HIG',
#  'HAS',
#  'HCA',
#  'HCP',
#  'HP',
#  'HSIC',
#  'HSY',
#  'HES',
#  'HPE',
#  'HLT',
#  'HFC',
#  'HOLX',
#  'HD',
#  'HON',
#  'HRL',
#  'HST',
#  'HPQ',
#  'HUM',
#  'HBAN',
#  'HII',
#  'IEX',
#  'IDXX',
#  'INFO',
#  'ITW',
#  'ILMN',
#  'IR',
#  'INTC',
#  'ICE',
#  'IBM',
#  'INCY',
#  'IP',
#  'IPG',
#  'IFF',
#  'INTU',
#  'ISRG',
#  'IVZ',
#  'IPGP',
#  'IQV',
#  'IRM',
#  'JKHY',
#  'JEC',
#  'JBHT',
#  'JEF',
#  'SJM',
#  'JNJ',
#  'JCI',
#  'JPM',
#  'JNPR',
#  'KSU',
#  'K',
#  'KEY',
#  'KEYS',
#  'KMB',
#  'KIM',
#  'KMI',
#  'KLAC',
#  'KSS',
#  'KHC',
#  'KR',
#  'LB',
#  'LHX',
#  'LH',
#  'LRCX',
#  'LW',
#  'LEG',
#  'LDOS',
#  'LEN',
#  'LLY',
#  'LNC',
#  'LIN',
#  'LKQ',
#  'LMT',
#  'L',
#  'LOW',
#  'LYB',
#  'MTB',
#  'MAC',
#  'M',
#  'MRO',
#  'MPC',
#  'MKTX',
#  'MAR',
#  'MMC',
#  'MLM',
#  'MAS',
#  'MA',
#  'MKC',
#  'MXIM',
#  'MCD',
#  'MCK',
#  'MDT',
#  'MRK',
#  'MET',
#  'MTD',
#  'MGM',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MAA',
#  'MHK',
#  'TAP',
#  'MDLZ',
#  'MNST',
#  'MCO',
#  'MS',
#  'MOS',
#  'MSI',
#  'MSCI',
#  'MYL',
#  'NDAQ',
#  'NOV',
#  'NKTR',
#  'NTAP',
#  'NFLX',
#  'NWL',
#  'NEM',
#  'NWSA',
#  'NWS',
#  'NEE',
#  'NLSN',
#  'NKE',
#  'NI',
#  'NBL',
#  'JWN',
#  'NSC',
#  'NTRS',
#  'NOC',
#  'NCLH',
#  'NRG',
#  'NUE',
#  'NVDA',
#  'ORLY',
#  'OXY',
#  'OMC',
#  'OKE',
#  'ORCL',
#  'PCAR',
#  'PKG',
#  'PH',
#  'PAYX',
#  'PYPL',
#  'PNR',
#  'PBCT',
#  'PEP',
#  'PKI',
#  'PRGO',
#  'PFE',
#  'PM',
#  'PSX',
#  'PNW',
#  'PXD',
#  'PNC',
#  'PPG',
#  'PPL',
#  'PFG',
#  'PG',
#  'PGR',
#  'PLD',
#  'PRU',
#  'PEG',
#  'PSA',
#  'PHM',
#  'PVH',
#  'QRVO',
#  'PWR',
#  'QCOM',
#  'DGX',
#  'RL',
#  'RJF',
#  'RTN',
#  'O',
#  'REG',
#  'REGN',
#  'RF',
#  'RSG',
#  'RMD',
#  'RHI',
#  'ROK',
#  'ROL',
#  'ROP',
#  'ROST',
#  'RCL',
#  'CRM',
#  'SBAC',
#  'SLB',
#  'STX',
#  'SEE',
#  'SRE',
#  'SHW',
#  'SPG',
#  'SWKS',
#  'SLG',
#  'SNA',
#  'SO',
#  'LUV',
#  'SPGI',
#  'SWK',
#  'SBUX',
#  'STT',
#  'SYK',
#  'STI',
#  'SIVB',
#  'SYMC',
#  'SYF',
#  'SNPS',
#  'SYY',
#  'TMUS',
#  'TROW',
#  'TTWO',
#  'TPR',
#  'TGT',
#  'TEL',
#  'FTI',
#  'TFX',
#  'TXN',
#  'TXT',
#  'TMO',
#  'TIF',
#  'TWTR',
#  'TJX',
#  'TSS',
#  'TSCO',
#  'TDG',
#  'TRV',
#  'TRIP',
#  'TSN',
#  'UDR',
#  'ULTA',
#  'USB',
#  'UAA',
#  'UA',
#  'UNP',
#  'UAL',
#  'UNH',
#  'UPS',
#  'URI',
#  'UTX',
#  'UHS',
#  'UNM',
#  'VFC',
#  'VLO',
#  'VAR',
#  'VTR',
#  'VRSN',
#  'VRSK',
#  'VZ',
#  'VRTX',
#  'VIAB',
#  'V',
#  'VNO',
#  'VMC',
#  'WAB',
#  'WMT',
#  'WBA',
#  'DIS',
#  'WM',
#  'WAT',
#  'WEC',
#  'WCG',
#  'WFC',
#  'WELL',
#  'WDC',
#  'WU',
#  'WRK',
#  'WY',
#  'WHR',
#  'WMB',
#  'WLTW',
#  'WYNN',
#  'XEL',
#  'XRX',
#  'XLNX',
#  'XYL',
#  'YUM',
#  'ZBH',
#  'ZION',
#  'ZTS']

# %%
# base_url = "https://cloud.iexapis.com/stable/stock/"
# key_token = "/quote?token=pk_e4c3fa15e49a4efca388fcfbcece0eac"

# # Empty list to store data
# stocks_data = []

# # Start counter for the loop

# symbol_counter = 1

# #symbols_list2 = ['MMM','ABT','AIG','HAL','SLB']

# #Print statement to inform when data acquisition start
# print(f"Beginning Data Acquisition!!!")
# print(f"------------&&&&-------------------")

# for symbol in tqdm(symbols_list):
#     try: 
#         response = requests.get(base_url+symbol+key_token).json()
#         stocks_data.append(response)
        
#         print(f"Data Acquisition {symbol_counter} | Stock Symbol : {symbol}")
#         symbol_counter = symbol_counter + 1
#     except:
#         print("Stock not found...!!")
#     continue
    
# # Print statement to inform when all records have been acquired.
# print(f"------------&&&&---------------")
# print(f"Data Acquisition Complete")
# print(f"------------&&&&---------------")
# Out:
# Beginning Data Acquisition!!!
# ------------&&&&-------------------
# HBox(children=(IntProgress(value=0, max=505), HTML(value='')))
# Data Acquisition 1 | Stock Symbol : MMM
# Data Acquisition 2 | Stock Symbol : ABT
# Data Acquisition 3 | Stock Symbol : ABBV
# Data Acquisition 4 | Stock Symbol : ABMD
# Data Acquisition 5 | Stock Symbol : ACN
# Data Acquisition 6 | Stock Symbol : ATVI
# Data Acquisition 7 | Stock Symbol : ADBE
# Data Acquisition 8 | Stock Symbol : AMD
# Data Acquisition 9 | Stock Symbol : AAP
# Data Acquisition 10 | Stock Symbol : AES
# Data Acquisition 11 | Stock Symbol : AMG
# Data Acquisition 12 | Stock Symbol : AFL
# Data Acquisition 13 | Stock Symbol : A
# Data Acquisition 14 | Stock Symbol : APD
# Data Acquisition 15 | Stock Symbol : AKAM
# Data Acquisition 16 | Stock Symbol : ALK
# Data Acquisition 17 | Stock Symbol : ALB
# Data Acquisition 18 | Stock Symbol : ARE
# Data Acquisition 19 | Stock Symbol : ALXN
# Data Acquisition 20 | Stock Symbol : ALGN
# Data Acquisition 21 | Stock Symbol : ALLE
# Data Acquisition 22 | Stock Symbol : AGN
# Data Acquisition 23 | Stock Symbol : ADS
# Data Acquisition 24 | Stock Symbol : LNT
# Data Acquisition 25 | Stock Symbol : ALL
# Data Acquisition 26 | Stock Symbol : GOOGL
# Data Acquisition 27 | Stock Symbol : GOOG
# Data Acquisition 28 | Stock Symbol : MO
# Data Acquisition 29 | Stock Symbol : AMZN
# Data Acquisition 30 | Stock Symbol : AMCR
# Data Acquisition 31 | Stock Symbol : AEE
# Data Acquisition 32 | Stock Symbol : AAL
# Data Acquisition 33 | Stock Symbol : AEP
# Data Acquisition 34 | Stock Symbol : AXP
# Data Acquisition 35 | Stock Symbol : AIG
# Data Acquisition 36 | Stock Symbol : AMT
# Data Acquisition 37 | Stock Symbol : AWK
# Data Acquisition 38 | Stock Symbol : AMP
# Data Acquisition 39 | Stock Symbol : ABC
# Data Acquisition 40 | Stock Symbol : AME
# Data Acquisition 41 | Stock Symbol : AMGN
# Data Acquisition 42 | Stock Symbol : APH
# Data Acquisition 43 | Stock Symbol : ADI
# Data Acquisition 44 | Stock Symbol : ANSS
# Data Acquisition 45 | Stock Symbol : ANTM
# Data Acquisition 46 | Stock Symbol : AON
# Data Acquisition 47 | Stock Symbol : AOS
# Data Acquisition 48 | Stock Symbol : APA
# Data Acquisition 49 | Stock Symbol : AIV
# Data Acquisition 50 | Stock Symbol : AAPL
# Data Acquisition 51 | Stock Symbol : AMAT
# Data Acquisition 52 | Stock Symbol : APTV
# Data Acquisition 53 | Stock Symbol : ADM
# Data Acquisition 54 | Stock Symbol : ARNC
# Data Acquisition 55 | Stock Symbol : ANET
# Data Acquisition 56 | Stock Symbol : AJG
# Data Acquisition 57 | Stock Symbol : AIZ
# Data Acquisition 58 | Stock Symbol : ATO
# Data Acquisition 59 | Stock Symbol : T
# Data Acquisition 60 | Stock Symbol : ADSK
# Data Acquisition 61 | Stock Symbol : ADP
# Data Acquisition 62 | Stock Symbol : AZO
# Data Acquisition 63 | Stock Symbol : AVB
# Data Acquisition 64 | Stock Symbol : AVY
# Data Acquisition 65 | Stock Symbol : BHGE
# Data Acquisition 66 | Stock Symbol : BLL
# Data Acquisition 67 | Stock Symbol : BAC
# Data Acquisition 68 | Stock Symbol : BK
# Data Acquisition 69 | Stock Symbol : BAX
# Data Acquisition 70 | Stock Symbol : BBT
# Data Acquisition 71 | Stock Symbol : BDX
# Data Acquisition 72 | Stock Symbol : BRK.B
# Data Acquisition 73 | Stock Symbol : BBY
# Data Acquisition 74 | Stock Symbol : BIIB
# Data Acquisition 75 | Stock Symbol : BLK
# Data Acquisition 76 | Stock Symbol : HRB
# Data Acquisition 77 | Stock Symbol : BA
# Data Acquisition 78 | Stock Symbol : BKNG
# Data Acquisition 79 | Stock Symbol : BWA
# Data Acquisition 80 | Stock Symbol : BXP
# Data Acquisition 81 | Stock Symbol : BSX
# Data Acquisition 82 | Stock Symbol : BMY
# Data Acquisition 83 | Stock Symbol : AVGO
# Data Acquisition 84 | Stock Symbol : BR
# Data Acquisition 85 | Stock Symbol : BF.B
# Data Acquisition 86 | Stock Symbol : CHRW
# Data Acquisition 87 | Stock Symbol : COG
# Data Acquisition 88 | Stock Symbol : CDNS
# Data Acquisition 89 | Stock Symbol : CPB
# Data Acquisition 90 | Stock Symbol : COF
# Data Acquisition 91 | Stock Symbol : CPRI
# Data Acquisition 92 | Stock Symbol : CAH
# Data Acquisition 93 | Stock Symbol : KMX
# Data Acquisition 94 | Stock Symbol : CCL
# Data Acquisition 95 | Stock Symbol : CAT
# Data Acquisition 96 | Stock Symbol : CBOE
# Data Acquisition 97 | Stock Symbol : CBRE
# Data Acquisition 98 | Stock Symbol : CBS
# Data Acquisition 99 | Stock Symbol : CE
# Data Acquisition 100 | Stock Symbol : CELG
# Data Acquisition 101 | Stock Symbol : CNC
# Data Acquisition 102 | Stock Symbol : CNP
# Data Acquisition 103 | Stock Symbol : CTL
# Data Acquisition 104 | Stock Symbol : CERN
# Data Acquisition 105 | Stock Symbol : CF
# Data Acquisition 106 | Stock Symbol : SCHW
# Data Acquisition 107 | Stock Symbol : CHTR
# Data Acquisition 108 | Stock Symbol : CVX
# Data Acquisition 109 | Stock Symbol : CMG
# Data Acquisition 110 | Stock Symbol : CB
# Data Acquisition 111 | Stock Symbol : CHD
# Data Acquisition 112 | Stock Symbol : CI
# Data Acquisition 113 | Stock Symbol : XEC
# Data Acquisition 114 | Stock Symbol : CINF
# Data Acquisition 115 | Stock Symbol : CTAS
# Data Acquisition 116 | Stock Symbol : CSCO
# Data Acquisition 117 | Stock Symbol : C
# Data Acquisition 118 | Stock Symbol : CFG
# Data Acquisition 119 | Stock Symbol : CTXS
# Data Acquisition 120 | Stock Symbol : CLX
# Data Acquisition 121 | Stock Symbol : CME
# Data Acquisition 122 | Stock Symbol : CMS
# Data Acquisition 123 | Stock Symbol : KO
# Data Acquisition 124 | Stock Symbol : CTSH
# Data Acquisition 125 | Stock Symbol : CL
# Data Acquisition 126 | Stock Symbol : CMCSA
# Data Acquisition 127 | Stock Symbol : CMA
# Data Acquisition 128 | Stock Symbol : CAG
# Data Acquisition 129 | Stock Symbol : CXO
# Data Acquisition 130 | Stock Symbol : COP
# Data Acquisition 131 | Stock Symbol : ED
# Data Acquisition 132 | Stock Symbol : STZ
# Data Acquisition 133 | Stock Symbol : COO
# Data Acquisition 134 | Stock Symbol : CPRT
# Data Acquisition 135 | Stock Symbol : GLW
# Data Acquisition 136 | Stock Symbol : CTVA
# Data Acquisition 137 | Stock Symbol : COST
# Data Acquisition 138 | Stock Symbol : COTY
# Data Acquisition 139 | Stock Symbol : CCI
# Data Acquisition 140 | Stock Symbol : CSX
# Data Acquisition 141 | Stock Symbol : CMI
# Data Acquisition 142 | Stock Symbol : CVS
# Data Acquisition 143 | Stock Symbol : DHI
# Data Acquisition 144 | Stock Symbol : DHR
# Data Acquisition 145 | Stock Symbol : DRI
# Data Acquisition 146 | Stock Symbol : DVA
# Data Acquisition 147 | Stock Symbol : DE
# Data Acquisition 148 | Stock Symbol : DAL
# Data Acquisition 149 | Stock Symbol : XRAY
# Data Acquisition 150 | Stock Symbol : DVN
# Data Acquisition 151 | Stock Symbol : FANG
# Data Acquisition 152 | Stock Symbol : DLR
# Data Acquisition 153 | Stock Symbol : DFS
# Data Acquisition 154 | Stock Symbol : DISCA
# Data Acquisition 155 | Stock Symbol : DISCK
# Data Acquisition 156 | Stock Symbol : DISH
# Data Acquisition 157 | Stock Symbol : DG
# Data Acquisition 158 | Stock Symbol : DLTR
# Data Acquisition 159 | Stock Symbol : D
# Data Acquisition 160 | Stock Symbol : DOV
# Data Acquisition 161 | Stock Symbol : DOW
# Data Acquisition 162 | Stock Symbol : DTE
# Data Acquisition 163 | Stock Symbol : DUK
# Data Acquisition 164 | Stock Symbol : DRE
# Data Acquisition 165 | Stock Symbol : DD
# Data Acquisition 166 | Stock Symbol : DXC
# Data Acquisition 167 | Stock Symbol : ETFC
# Data Acquisition 168 | Stock Symbol : EMN
# Data Acquisition 169 | Stock Symbol : ETN
# Data Acquisition 170 | Stock Symbol : EBAY
# Data Acquisition 171 | Stock Symbol : ECL
# Data Acquisition 172 | Stock Symbol : EIX
# Data Acquisition 173 | Stock Symbol : EW
# Data Acquisition 174 | Stock Symbol : EA
# Data Acquisition 175 | Stock Symbol : EMR
# Data Acquisition 176 | Stock Symbol : ETR
# Data Acquisition 177 | Stock Symbol : EOG
# Data Acquisition 178 | Stock Symbol : EFX
# Data Acquisition 179 | Stock Symbol : EQIX
# Data Acquisition 180 | Stock Symbol : EQR
# Data Acquisition 181 | Stock Symbol : ESS
# Data Acquisition 182 | Stock Symbol : EL
# Data Acquisition 183 | Stock Symbol : EVRG
# Data Acquisition 184 | Stock Symbol : ES
# Data Acquisition 185 | Stock Symbol : RE
# Data Acquisition 186 | Stock Symbol : EXC
# Data Acquisition 187 | Stock Symbol : EXPE
# Data Acquisition 188 | Stock Symbol : EXPD
# Data Acquisition 189 | Stock Symbol : EXR
# Data Acquisition 190 | Stock Symbol : XOM
# Data Acquisition 191 | Stock Symbol : FFIV
# Data Acquisition 192 | Stock Symbol : FB
# Data Acquisition 193 | Stock Symbol : FAST
# Data Acquisition 194 | Stock Symbol : FRT
# Data Acquisition 195 | Stock Symbol : FDX
# Data Acquisition 196 | Stock Symbol : FIS
# Data Acquisition 197 | Stock Symbol : FITB
# Data Acquisition 198 | Stock Symbol : FE
# Data Acquisition 199 | Stock Symbol : FRC
# Data Acquisition 200 | Stock Symbol : FISV
# Data Acquisition 201 | Stock Symbol : FLT
# Data Acquisition 202 | Stock Symbol : FLIR
# Data Acquisition 203 | Stock Symbol : FLS
# Data Acquisition 204 | Stock Symbol : FMC
# Data Acquisition 205 | Stock Symbol : F
# Data Acquisition 206 | Stock Symbol : FTNT
# Data Acquisition 207 | Stock Symbol : FTV
# Data Acquisition 208 | Stock Symbol : FBHS
# Data Acquisition 209 | Stock Symbol : FOXA
# Data Acquisition 210 | Stock Symbol : FOX
# Data Acquisition 211 | Stock Symbol : BEN
# Data Acquisition 212 | Stock Symbol : FCX
# Data Acquisition 213 | Stock Symbol : GPS
# Data Acquisition 214 | Stock Symbol : GRMN
# Data Acquisition 215 | Stock Symbol : IT
# Data Acquisition 216 | Stock Symbol : GD
# Data Acquisition 217 | Stock Symbol : GE
# Data Acquisition 218 | Stock Symbol : GIS
# Data Acquisition 219 | Stock Symbol : GM
# Data Acquisition 220 | Stock Symbol : GPC
# Data Acquisition 221 | Stock Symbol : GILD
# Data Acquisition 222 | Stock Symbol : GL
# Data Acquisition 223 | Stock Symbol : GPN
# Data Acquisition 224 | Stock Symbol : GS
# Data Acquisition 225 | Stock Symbol : GWW
# Data Acquisition 226 | Stock Symbol : HAL
# Data Acquisition 227 | Stock Symbol : HBI
# Data Acquisition 228 | Stock Symbol : HOG
# Data Acquisition 229 | Stock Symbol : HIG
# Data Acquisition 230 | Stock Symbol : HAS
# Data Acquisition 231 | Stock Symbol : HCA
# Data Acquisition 232 | Stock Symbol : HCP
# Data Acquisition 233 | Stock Symbol : HP
# Data Acquisition 234 | Stock Symbol : HSIC
# Data Acquisition 235 | Stock Symbol : HSY
# Data Acquisition 236 | Stock Symbol : HES
# Data Acquisition 237 | Stock Symbol : HPE
# Data Acquisition 238 | Stock Symbol : HLT
# Data Acquisition 239 | Stock Symbol : HFC
# Data Acquisition 240 | Stock Symbol : HOLX
# Data Acquisition 241 | Stock Symbol : HD
# Data Acquisition 242 | Stock Symbol : HON
# Data Acquisition 243 | Stock Symbol : HRL
# Data Acquisition 244 | Stock Symbol : HST
# Data Acquisition 245 | Stock Symbol : HPQ
# Data Acquisition 246 | Stock Symbol : HUM
# Data Acquisition 247 | Stock Symbol : HBAN
# Data Acquisition 248 | Stock Symbol : HII
# Data Acquisition 249 | Stock Symbol : IEX
# Data Acquisition 250 | Stock Symbol : IDXX
# Data Acquisition 251 | Stock Symbol : INFO
# Data Acquisition 252 | Stock Symbol : ITW
# Data Acquisition 253 | Stock Symbol : ILMN
# Data Acquisition 254 | Stock Symbol : IR
# Data Acquisition 255 | Stock Symbol : INTC
# Data Acquisition 256 | Stock Symbol : ICE
# Data Acquisition 257 | Stock Symbol : IBM
# Data Acquisition 258 | Stock Symbol : INCY
# Data Acquisition 259 | Stock Symbol : IP
# Data Acquisition 260 | Stock Symbol : IPG
# Data Acquisition 261 | Stock Symbol : IFF
# Data Acquisition 262 | Stock Symbol : INTU
# Data Acquisition 263 | Stock Symbol : ISRG
# Data Acquisition 264 | Stock Symbol : IVZ
# Data Acquisition 265 | Stock Symbol : IPGP
# Data Acquisition 266 | Stock Symbol : IQV
# Data Acquisition 267 | Stock Symbol : IRM
# Data Acquisition 268 | Stock Symbol : JKHY
# Data Acquisition 269 | Stock Symbol : JEC
# Data Acquisition 270 | Stock Symbol : JBHT
# Data Acquisition 271 | Stock Symbol : JEF
# Data Acquisition 272 | Stock Symbol : SJM
# Data Acquisition 273 | Stock Symbol : JNJ
# Data Acquisition 274 | Stock Symbol : JCI
# Data Acquisition 275 | Stock Symbol : JPM
# Data Acquisition 276 | Stock Symbol : JNPR
# Data Acquisition 277 | Stock Symbol : KSU
# Data Acquisition 278 | Stock Symbol : K
# Data Acquisition 279 | Stock Symbol : KEY
# Data Acquisition 280 | Stock Symbol : KEYS
# Data Acquisition 281 | Stock Symbol : KMB
# Data Acquisition 282 | Stock Symbol : KIM
# Data Acquisition 283 | Stock Symbol : KMI
# Data Acquisition 284 | Stock Symbol : KLAC
# Data Acquisition 285 | Stock Symbol : KSS
# Data Acquisition 286 | Stock Symbol : KHC
# Data Acquisition 287 | Stock Symbol : KR
# Data Acquisition 288 | Stock Symbol : LB
# Data Acquisition 289 | Stock Symbol : LHX
# Data Acquisition 290 | Stock Symbol : LH
# Data Acquisition 291 | Stock Symbol : LRCX
# Data Acquisition 292 | Stock Symbol : LW
# Data Acquisition 293 | Stock Symbol : LEG
# Data Acquisition 294 | Stock Symbol : LDOS
# Data Acquisition 295 | Stock Symbol : LEN
# Data Acquisition 296 | Stock Symbol : LLY
# Data Acquisition 297 | Stock Symbol : LNC
# Data Acquisition 298 | Stock Symbol : LIN
# Data Acquisition 299 | Stock Symbol : LKQ
# Data Acquisition 300 | Stock Symbol : LMT
# Data Acquisition 301 | Stock Symbol : L
# Data Acquisition 302 | Stock Symbol : LOW
# Data Acquisition 303 | Stock Symbol : LYB
# Data Acquisition 304 | Stock Symbol : MTB
# Data Acquisition 305 | Stock Symbol : MAC
# Data Acquisition 306 | Stock Symbol : M
# Data Acquisition 307 | Stock Symbol : MRO
# Data Acquisition 308 | Stock Symbol : MPC
# Data Acquisition 309 | Stock Symbol : MKTX
# Data Acquisition 310 | Stock Symbol : MAR
# Data Acquisition 311 | Stock Symbol : MMC
# Data Acquisition 312 | Stock Symbol : MLM
# Data Acquisition 313 | Stock Symbol : MAS
# Data Acquisition 314 | Stock Symbol : MA
# Data Acquisition 315 | Stock Symbol : MKC
# Data Acquisition 316 | Stock Symbol : MXIM
# Data Acquisition 317 | Stock Symbol : MCD
# Data Acquisition 318 | Stock Symbol : MCK
# Data Acquisition 319 | Stock Symbol : MDT
# Data Acquisition 320 | Stock Symbol : MRK
# Data Acquisition 321 | Stock Symbol : MET
# Data Acquisition 322 | Stock Symbol : MTD
# Data Acquisition 323 | Stock Symbol : MGM
# Data Acquisition 324 | Stock Symbol : MCHP
# Data Acquisition 325 | Stock Symbol : MU
# Data Acquisition 326 | Stock Symbol : MSFT
# Data Acquisition 327 | Stock Symbol : MAA
# Data Acquisition 328 | Stock Symbol : MHK
# Data Acquisition 329 | Stock Symbol : TAP
# Data Acquisition 330 | Stock Symbol : MDLZ
# Data Acquisition 331 | Stock Symbol : MNST
# Data Acquisition 332 | Stock Symbol : MCO
# Data Acquisition 333 | Stock Symbol : MS
# Data Acquisition 334 | Stock Symbol : MOS
# Data Acquisition 335 | Stock Symbol : MSI
# Data Acquisition 336 | Stock Symbol : MSCI
# Data Acquisition 337 | Stock Symbol : MYL
# Data Acquisition 338 | Stock Symbol : NDAQ
# Data Acquisition 339 | Stock Symbol : NOV
# Data Acquisition 340 | Stock Symbol : NKTR
# Data Acquisition 341 | Stock Symbol : NTAP
# Data Acquisition 342 | Stock Symbol : NFLX
# Data Acquisition 343 | Stock Symbol : NWL
# Data Acquisition 344 | Stock Symbol : NEM
# Data Acquisition 345 | Stock Symbol : NWSA
# Data Acquisition 346 | Stock Symbol : NWS
# Data Acquisition 347 | Stock Symbol : NEE
# Data Acquisition 348 | Stock Symbol : NLSN
# Data Acquisition 349 | Stock Symbol : NKE
# Data Acquisition 350 | Stock Symbol : NI
# Data Acquisition 351 | Stock Symbol : NBL
# Data Acquisition 352 | Stock Symbol : JWN
# Data Acquisition 353 | Stock Symbol : NSC
# Data Acquisition 354 | Stock Symbol : NTRS
# Data Acquisition 355 | Stock Symbol : NOC
# Data Acquisition 356 | Stock Symbol : NCLH
# Data Acquisition 357 | Stock Symbol : NRG
# Data Acquisition 358 | Stock Symbol : NUE
# Data Acquisition 359 | Stock Symbol : NVDA
# Data Acquisition 360 | Stock Symbol : ORLY
# Data Acquisition 361 | Stock Symbol : OXY
# Data Acquisition 362 | Stock Symbol : OMC
# Data Acquisition 363 | Stock Symbol : OKE
# Data Acquisition 364 | Stock Symbol : ORCL
# Data Acquisition 365 | Stock Symbol : PCAR
# Data Acquisition 366 | Stock Symbol : PKG
# Data Acquisition 367 | Stock Symbol : PH
# Data Acquisition 368 | Stock Symbol : PAYX
# Data Acquisition 369 | Stock Symbol : PYPL
# Data Acquisition 370 | Stock Symbol : PNR
# Data Acquisition 371 | Stock Symbol : PBCT
# Data Acquisition 372 | Stock Symbol : PEP
# Data Acquisition 373 | Stock Symbol : PKI
# Data Acquisition 374 | Stock Symbol : PRGO
# Data Acquisition 375 | Stock Symbol : PFE
# Data Acquisition 376 | Stock Symbol : PM
# Data Acquisition 377 | Stock Symbol : PSX
# Data Acquisition 378 | Stock Symbol : PNW
# Data Acquisition 379 | Stock Symbol : PXD
# Data Acquisition 380 | Stock Symbol : PNC
# Data Acquisition 381 | Stock Symbol : PPG
# Data Acquisition 382 | Stock Symbol : PPL
# Data Acquisition 383 | Stock Symbol : PFG
# Data Acquisition 384 | Stock Symbol : PG
# Data Acquisition 385 | Stock Symbol : PGR
# Data Acquisition 386 | Stock Symbol : PLD
# Data Acquisition 387 | Stock Symbol : PRU
# Data Acquisition 388 | Stock Symbol : PEG
# Data Acquisition 389 | Stock Symbol : PSA
# Data Acquisition 390 | Stock Symbol : PHM
# Data Acquisition 391 | Stock Symbol : PVH
# Data Acquisition 392 | Stock Symbol : QRVO
# Data Acquisition 393 | Stock Symbol : PWR
# Data Acquisition 394 | Stock Symbol : QCOM
# Data Acquisition 395 | Stock Symbol : DGX
# Data Acquisition 396 | Stock Symbol : RL
# Data Acquisition 397 | Stock Symbol : RJF
# Data Acquisition 398 | Stock Symbol : RTN
# Data Acquisition 399 | Stock Symbol : O
# Data Acquisition 400 | Stock Symbol : REG
# Data Acquisition 401 | Stock Symbol : REGN
# Data Acquisition 402 | Stock Symbol : RF
# Data Acquisition 403 | Stock Symbol : RSG
# Data Acquisition 404 | Stock Symbol : RMD
# Data Acquisition 405 | Stock Symbol : RHI
# Data Acquisition 406 | Stock Symbol : ROK
# Data Acquisition 407 | Stock Symbol : ROL
# Data Acquisition 408 | Stock Symbol : ROP
# Data Acquisition 409 | Stock Symbol : ROST
# Data Acquisition 410 | Stock Symbol : RCL
# Data Acquisition 411 | Stock Symbol : CRM
# Data Acquisition 412 | Stock Symbol : SBAC
# Data Acquisition 413 | Stock Symbol : SLB
# Data Acquisition 414 | Stock Symbol : STX
# Data Acquisition 415 | Stock Symbol : SEE
# Data Acquisition 416 | Stock Symbol : SRE
# Data Acquisition 417 | Stock Symbol : SHW
# Data Acquisition 418 | Stock Symbol : SPG
# Data Acquisition 419 | Stock Symbol : SWKS
# Data Acquisition 420 | Stock Symbol : SLG
# Data Acquisition 421 | Stock Symbol : SNA
# Data Acquisition 422 | Stock Symbol : SO
# Data Acquisition 423 | Stock Symbol : LUV
# Data Acquisition 424 | Stock Symbol : SPGI
# Data Acquisition 425 | Stock Symbol : SWK
# Data Acquisition 426 | Stock Symbol : SBUX
# Data Acquisition 427 | Stock Symbol : STT
# Data Acquisition 428 | Stock Symbol : SYK
# Data Acquisition 429 | Stock Symbol : STI
# Data Acquisition 430 | Stock Symbol : SIVB
# Data Acquisition 431 | Stock Symbol : SYMC
# Data Acquisition 432 | Stock Symbol : SYF
# Data Acquisition 433 | Stock Symbol : SNPS
# Data Acquisition 434 | Stock Symbol : SYY
# Data Acquisition 435 | Stock Symbol : TMUS
# Data Acquisition 436 | Stock Symbol : TROW
# Data Acquisition 437 | Stock Symbol : TTWO
# Data Acquisition 438 | Stock Symbol : TPR
# Data Acquisition 439 | Stock Symbol : TGT
# Data Acquisition 440 | Stock Symbol : TEL
# Data Acquisition 441 | Stock Symbol : FTI
# Data Acquisition 442 | Stock Symbol : TFX
# Data Acquisition 443 | Stock Symbol : TXN
# Data Acquisition 444 | Stock Symbol : TXT
# Data Acquisition 445 | Stock Symbol : TMO
# Data Acquisition 446 | Stock Symbol : TIF
# Data Acquisition 447 | Stock Symbol : TWTR
# Data Acquisition 448 | Stock Symbol : TJX
# Data Acquisition 449 | Stock Symbol : TSS
# Data Acquisition 450 | Stock Symbol : TSCO
# Data Acquisition 451 | Stock Symbol : TDG
# Data Acquisition 452 | Stock Symbol : TRV
# Data Acquisition 453 | Stock Symbol : TRIP
# Data Acquisition 454 | Stock Symbol : TSN
# Data Acquisition 455 | Stock Symbol : UDR
# Data Acquisition 456 | Stock Symbol : ULTA
# Data Acquisition 457 | Stock Symbol : USB
# Data Acquisition 458 | Stock Symbol : UAA
# Data Acquisition 459 | Stock Symbol : UA
# Data Acquisition 460 | Stock Symbol : UNP
# Data Acquisition 461 | Stock Symbol : UAL
# Data Acquisition 462 | Stock Symbol : UNH
# Data Acquisition 463 | Stock Symbol : UPS
# Data Acquisition 464 | Stock Symbol : URI
# Data Acquisition 465 | Stock Symbol : UTX
# Data Acquisition 466 | Stock Symbol : UHS
# Data Acquisition 467 | Stock Symbol : UNM
# Data Acquisition 468 | Stock Symbol : VFC
# Data Acquisition 469 | Stock Symbol : VLO
# Data Acquisition 470 | Stock Symbol : VAR
# Data Acquisition 471 | Stock Symbol : VTR
# Data Acquisition 472 | Stock Symbol : VRSN
# Data Acquisition 473 | Stock Symbol : VRSK
# Data Acquisition 474 | Stock Symbol : VZ
# Data Acquisition 475 | Stock Symbol : VRTX
# Data Acquisition 476 | Stock Symbol : VIAB
# Data Acquisition 477 | Stock Symbol : V
# Data Acquisition 478 | Stock Symbol : VNO
# Data Acquisition 479 | Stock Symbol : VMC
# Data Acquisition 480 | Stock Symbol : WAB
# Data Acquisition 481 | Stock Symbol : WMT
# Data Acquisition 482 | Stock Symbol : WBA
# Data Acquisition 483 | Stock Symbol : DIS
# Data Acquisition 484 | Stock Symbol : WM
# Data Acquisition 485 | Stock Symbol : WAT
# Data Acquisition 486 | Stock Symbol : WEC
# Data Acquisition 487 | Stock Symbol : WCG
# Data Acquisition 488 | Stock Symbol : WFC
# Data Acquisition 489 | Stock Symbol : WELL
# Data Acquisition 490 | Stock Symbol : WDC
# Data Acquisition 491 | Stock Symbol : WU
# Data Acquisition 492 | Stock Symbol : WRK
# Data Acquisition 493 | Stock Symbol : WY
# Data Acquisition 494 | Stock Symbol : WHR
# Data Acquisition 495 | Stock Symbol : WMB
# Data Acquisition 496 | Stock Symbol : WLTW
# Data Acquisition 497 | Stock Symbol : WYNN
# Data Acquisition 498 | Stock Symbol : XEL
# Data Acquisition 499 | Stock Symbol : XRX
# Data Acquisition 500 | Stock Symbol : XLNX
# Data Acquisition 501 | Stock Symbol : XYL
# Data Acquisition 502 | Stock Symbol : YUM
# Data Acquisition 503 | Stock Symbol : ZBH
# Data Acquisition 504 | Stock Symbol : ZION
# Data Acquisition 505 | Stock Symbol : ZTS
#
# ------------&&&&---------------
# Data Acquisition Complete
# ------------&&&&---------------

# %%
stocks_data
# Out:
# [{'symbol': 'MMM',
#   'companyName': '3M Co.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 161.4,
#   'openTime': 1567517405225,
#   'close': 158.64,
#   'closeTime': 1567483200000,
#   'high': 161.63,
#   'low': 157.26,
#   'latestPrice': 158.64,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1838159,
#   'iexRealtimePrice': 158.64,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540795020,
#   'delayedPrice': 158.64,
#   'delayedPriceTime': 1567541400011,
#   'extendedPrice': 158.64,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800002,
#   'previousClose': 161.72,
#   'previousVolume': 1967010,
#   'change': -3.08,
#   'changePercent': -0.01905,
#   'volume': 1838159,
#   'iexMarketPercent': 0.03346337286382734,
#   'iexVolume': 61511,
#   'avgTotalVolume': 3000058,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 91262260560,
#   'peRatio': 18.79,
#   'week52High': 219.75,
#   'week52Low': 154,
#   'ytdChange': -0.172127,
#   'lastTradeTime': 1567540795020,
#   'isUSMarketOpen': False},
#  {'symbol': 'ABT',
#   'companyName': 'Abbott Laboratories',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 84.35,
#   'openTime': 1567517539113,
#   'close': 84.06,
#   'closeTime': 1567483200000,
#   'high': 84.64,
#   'low': 83.26,
#   'latestPrice': 84.06,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 4067856,
#   'iexRealtimePrice': 84.05,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794194,
#   'delayedPrice': 84.06,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 84.06,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 85.32,
#   'previousVolume': 3628594,
#   'change': -1.26,
#   'changePercent': -0.01477,
#   'volume': 4067856,
#   'iexMarketPercent': 0.053714782430843176,
#   'iexVolume': 218504,
#   'avgTotalVolume': 4573684,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 148567644000,
#   'peRatio': 51.26,
#   'week52High': 88.76,
#   'week52Low': 65.22,
#   'ytdChange': 0.212856,
#   'lastTradeTime': 1567540794194,
#   'isUSMarketOpen': False},
#  {'symbol': 'ABBV',
#   'companyName': 'AbbVie, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 65.67,
#   'openTime': 1567517426522,
#   'close': 65.4,
#   'closeTime': 1567483200000,
#   'high': 65.8,
#   'low': 64.93,
#   'latestPrice': 65.4,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 7935203,
#   'iexRealtimePrice': 65.39,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540797933,
#   'delayedPrice': 65.4,
#   'delayedPriceTime': 1567541400013,
#   'extendedPrice': 65.5,
#   'extendedChange': 0.1,
#   'extendedChangePercent': 0.00153,
#   'extendedPriceTime': 1567552684712,
#   'previousClose': 65.74,
#   'previousVolume': 6415479,
#   'change': -0.34,
#   'changePercent': -0.00517,
#   'volume': 7935203,
#   'iexMarketPercent': 0.04449527000128415,
#   'iexVolume': 353079,
#   'avgTotalVolume': 9090799,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 96692592000,
#   'peRatio': 24,
#   'week52High': 96.6,
#   'week52Low': 62.66,
#   'ytdChange': -0.268422,
#   'lastTradeTime': 1567540797933,
#   'isUSMarketOpen': False},
#  {'symbol': 'ABMD',
#   'companyName': 'ABIOMED, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 192.08,
#   'openTime': 1567517400755,
#   'close': 183.64,
#   'closeTime': 1567483200000,
#   'high': 192.47,
#   'low': 182.05,
#   'latestPrice': 183.64,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 647398,
#   'iexRealtimePrice': 183.54,
#   'iexRealtimeSize': 18,
#   'iexLastUpdated': 1567540767085,
#   'delayedPrice': 183.64,
#   'delayedPriceTime': 1567540800252,
#   'extendedPrice': 184,
#   'extendedChange': 0.36,
#   'extendedChangePercent': 0.00196,
#   'extendedPriceTime': 1567553110730,
#   'previousClose': 193.07,
#   'previousVolume': 397103,
#   'change': -9.43,
#   'changePercent': -0.04884,
#   'volume': 647398,
#   'iexMarketPercent': 0.052622961454931894,
#   'iexVolume': 34068,
#   'avgTotalVolume': 716532,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 8333032280,
#   'peRatio': 32.12,
#   'week52High': 459.75,
#   'week52Low': 181.02,
#   'ytdChange': -0.42595299999999997,
#   'lastTradeTime': 1567540201642,
#   'isUSMarketOpen': False},
#  {'symbol': 'ACN',
#   'companyName': 'Accenture Plc',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 196.36,
#   'openTime': 1567517400485,
#   'close': 195.75,
#   'closeTime': 1567483200000,
#   'high': 197.76,
#   'low': 195.44,
#   'latestPrice': 195.75,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1699091,
#   'iexRealtimePrice': 195.75,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540797766,
#   'delayedPrice': 195.75,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 195.75,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 198.17,
#   'previousVolume': 2176628,
#   'change': -2.42,
#   'changePercent': -0.01221,
#   'volume': 1699091,
#   'iexMarketPercent': 0.03987190797903114,
#   'iexVolume': 67746,
#   'avgTotalVolume': 1724995,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 124720350750,
#   'peRatio': 26.71,
#   'week52High': 200.68,
#   'week52Low': 132.63,
#   'ytdChange': 0.39735,
#   'lastTradeTime': 1567540797766,
#   'isUSMarketOpen': False},
#  {'symbol': 'ATVI',
#   'companyName': 'Activision Blizzard, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 50.48,
#   'openTime': 1567517400700,
#   'close': 51.06,
#   'closeTime': 1567483200000,
#   'high': 51.57,
#   'low': 50.43,
#   'latestPrice': 51.06,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 6272025,
#   'iexRealtimePrice': 51.01,
#   'iexRealtimeSize': 90,
#   'iexLastUpdated': 1567540781236,
#   'delayedPrice': 51.06,
#   'delayedPriceTime': 1567540800228,
#   'extendedPrice': 51.39,
#   'extendedChange': 0.33,
#   'extendedChangePercent': 0.00646,
#   'extendedPriceTime': 1567547892567,
#   'previousClose': 50.6,
#   'previousVolume': 5891610,
#   'change': 0.46,
#   'changePercent': 0.00909,
#   'volume': 6272025,
#   'iexMarketPercent': 0.041999992028093,
#   'iexVolume': 263425,
#   'avgTotalVolume': 7000154,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 39164347560,
#   'peRatio': 23.16,
#   'week52High': 84.67,
#   'week52Low': 39.85,
#   'ytdChange': 0.084999,
#   'lastTradeTime': 1567540625696,
#   'isUSMarketOpen': False},
#  {'symbol': 'ADBE',
#   'companyName': 'Adobe, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 284.25,
#   'openTime': 1567517400873,
#   'close': 282.45,
#   'closeTime': 1567483200000,
#   'high': 287.46,
#   'low': 281.4,
#   'latestPrice': 282.45,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1838768,
#   'iexRealtimePrice': 282.39,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794050,
#   'delayedPrice': 282.45,
#   'delayedPriceTime': 1567540800614,
#   'extendedPrice': 282.88,
#   'extendedChange': 0.43,
#   'extendedChangePercent': 0.00152,
#   'extendedPriceTime': 1567553559508,
#   'previousClose': 284.51,
#   'previousVolume': 2373297,
#   'change': -2.06,
#   'changePercent': -0.00724,
#   'volume': 1838768,
#   'iexMarketPercent': 0.03363121394324896,
#   'iexVolume': 61840,
#   'avgTotalVolume': 2231047,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 137112245550,
#   'peRatio': 52.02,
#   'week52High': 313.11,
#   'week52Low': 204.95,
#   'ytdChange': 0.25966999999999996,
#   'lastTradeTime': 1567540664042,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMD',
#   'companyName': 'Advanced Micro Devices, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 30.83,
#   'openTime': 1567517400511,
#   'close': 30.9,
#   'closeTime': 1567483200000,
#   'high': 31.14,
#   'low': 30.68,
#   'latestPrice': 30.9,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 38001364,
#   'iexRealtimePrice': 30.885,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794146,
#   'delayedPrice': 30.9,
#   'delayedPriceTime': 1567541700009,
#   'extendedPrice': 30.94,
#   'extendedChange': 0.04,
#   'extendedChangePercent': 0.00129,
#   'extendedPriceTime': 1567554009760,
#   'previousClose': 31.45,
#   'previousVolume': 40347321,
#   'change': -0.55,
#   'changePercent': -0.01749,
#   'volume': 38001364,
#   'iexMarketPercent': 0.010026324318253418,
#   'iexVolume': 381014,
#   'avgTotalVolume': 69530176,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 33543495000,
#   'peRatio': 164.71,
#   'week52High': 35.55,
#   'week52Low': 16.03,
#   'ytdChange': 0.652717,
#   'lastTradeTime': 1567540761887,
#   'isUSMarketOpen': False},
#  {'symbol': 'AAP',
#   'companyName': 'Advance Auto Parts, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 137.19,
#   'openTime': 1567517400419,
#   'close': 140.36,
#   'closeTime': 1567483200000,
#   'high': 140.43,
#   'low': 136.77,
#   'latestPrice': 140.36,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1002812,
#   'iexRealtimePrice': 140.41,
#   'iexRealtimeSize': 28,
#   'iexLastUpdated': 1567540759869,
#   'delayedPrice': 140.36,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 140.36,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 137.95,
#   'previousVolume': 721325,
#   'change': 2.41,
#   'changePercent': 0.01747,
#   'volume': 1002812,
#   'iexMarketPercent': 0.032714008208916526,
#   'iexVolume': 32806,
#   'avgTotalVolume': 1423485,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 10019879320,
#   'peRatio': 23.29,
#   'week52High': 186.15,
#   'week52Low': 130.09,
#   'ytdChange': -0.10898600000000001,
#   'lastTradeTime': 1567540759869,
#   'isUSMarketOpen': False},
#  {'symbol': 'AES',
#   'companyName': 'The AES Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 15.22,
#   'openTime': 1567517400433,
#   'close': 15.34,
#   'closeTime': 1567483200000,
#   'high': 15.45,
#   'low': 15.17,
#   'latestPrice': 15.34,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 5745858,
#   'iexRealtimePrice': 15.315,
#   'iexRealtimeSize': 200,
#   'iexLastUpdated': 1567540774355,
#   'delayedPrice': 15.34,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 15.34,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 15.33,
#   'previousVolume': 5110186,
#   'change': 0.01,
#   'changePercent': 0.00065,
#   'volume': 5745858,
#   'iexMarketPercent': 0.03388980375080623,
#   'iexVolume': 194726,
#   'avgTotalVolume': 5118649,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 10183459000,
#   'peRatio': 25.67,
#   'week52High': 18.52,
#   'week52Low': 13,
#   'ytdChange': 0.08175,
#   'lastTradeTime': 1567540774355,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMG',
#   'companyName': 'Affiliated Managers Group, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 75.85,
#   'openTime': 1567517400416,
#   'close': 74.97,
#   'closeTime': 1567483200000,
#   'high': 76.02,
#   'low': 74.19,
#   'latestPrice': 74.97,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 390163,
#   'iexRealtimePrice': 74.97,
#   'iexRealtimeSize': 37,
#   'iexLastUpdated': 1567540794063,
#   'delayedPrice': 74.97,
#   'delayedPriceTime': 1567541400005,
#   'extendedPrice': 74.97,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800004,
#   'previousClose': 76.63,
#   'previousVolume': 377886,
#   'change': -1.66,
#   'changePercent': -0.02166,
#   'volume': 390163,
#   'iexMarketPercent': 0.02130647959955198,
#   'iexVolume': 8313,
#   'avgTotalVolume': 544172,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 3796480800,
#   'peRatio': -32.78,
#   'week52High': 147.94,
#   'week52Low': 73.9,
#   'ytdChange': -0.241552,
#   'lastTradeTime': 1567540794063,
#   'isUSMarketOpen': False},
#  {'symbol': 'AFL',
#   'companyName': 'Aflac, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 49.75,
#   'openTime': 1567517400449,
#   'close': 50.38,
#   'closeTime': 1567483200000,
#   'high': 50.43,
#   'low': 49.6,
#   'latestPrice': 50.38,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 3778151,
#   'iexRealtimePrice': 50.37,
#   'iexRealtimeSize': 80,
#   'iexLastUpdated': 1567540790854,
#   'delayedPrice': 50.38,
#   'delayedPriceTime': 1567541400004,
#   'extendedPrice': 50.38,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 50.18,
#   'previousVolume': 3867882,
#   'change': 0.2,
#   'changePercent': 0.00399,
#   'volume': 3778151,
#   'iexMarketPercent': 0.02475655419807202,
#   'iexVolume': 93534,
#   'avgTotalVolume': 3681345,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 37300495540,
#   'peRatio': 12.23,
#   'week52High': 57.18,
#   'week52Low': 41.44,
#   'ytdChange': 0.106363,
#   'lastTradeTime': 1567540790854,
#   'isUSMarketOpen': False},
#  {'symbol': 'A',
#   'companyName': 'Agilent Technologies, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 70.7,
#   'openTime': 1567517403499,
#   'close': 70.41,
#   'closeTime': 1567483200000,
#   'high': 71.04,
#   'low': 69.481,
#   'latestPrice': 70.41,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2229118,
#   'iexRealtimePrice': 70.42,
#   'iexRealtimeSize': 2,
#   'iexLastUpdated': 1567540795563,
#   'delayedPrice': 70.41,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 70.41,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 71.11,
#   'previousVolume': 2356396,
#   'change': -0.7,
#   'changePercent': -0.00984,
#   'volume': 2229118,
#   'iexMarketPercent': 0.03810161687268238,
#   'iexVolume': 84933,
#   'avgTotalVolume': 2615599,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 22249067130,
#   'peRatio': 20.82,
#   'week52High': 82.27,
#   'week52Low': 61.01,
#   'ytdChange': 0.072669,
#   'lastTradeTime': 1567540795563,
#   'isUSMarketOpen': False},
#  {'symbol': 'APD',
#   'companyName': 'Air Products & Chemicals, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 223.97,
#   'openTime': 1567517400428,
#   'close': 225.56,
#   'closeTime': 1567483200000,
#   'high': 226.26,
#   'low': 223.69,
#   'latestPrice': 225.56,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 732226,
#   'iexRealtimePrice': 225.45,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540783039,
#   'delayedPrice': 225.56,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 225.56,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800001,
#   'previousClose': 225.92,
#   'previousVolume': 878094,
#   'change': -0.36,
#   'changePercent': -0.00159,
#   'volume': 732226,
#   'iexMarketPercent': 0.04130828460065608,
#   'iexVolume': 30247,
#   'avgTotalVolume': 998370,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 49703273800,
#   'peRatio': 29.06,
#   'week52High': 232.46,
#   'week52Low': 148.44,
#   'ytdChange': 0.414038,
#   'lastTradeTime': 1567540783039,
#   'isUSMarketOpen': False},
#  {'symbol': 'AKAM',
#   'companyName': 'Akamai Technologies, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 88.86,
#   'openTime': 1567517400841,
#   'close': 89.12,
#   'closeTime': 1567483200000,
#   'high': 89.72,
#   'low': 88.38,
#   'latestPrice': 89.12,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1445595,
#   'iexRealtimePrice': 89.12,
#   'iexRealtimeSize': 69,
#   'iexLastUpdated': 1567540795215,
#   'delayedPrice': 89.12,
#   'delayedPriceTime': 1567540800477,
#   'extendedPrice': 89,
#   'extendedChange': -0.12,
#   'extendedChangePercent': -0.00135,
#   'extendedPriceTime': 1567552200833,
#   'previousClose': 89.13,
#   'previousVolume': 1159643,
#   'change': -0.01,
#   'changePercent': -0.00011,
#   'volume': 1445595,
#   'iexMarketPercent': 0.031456943334751436,
#   'iexVolume': 45474,
#   'avgTotalVolume': 1750220,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 14703195840,
#   'peRatio': 34.41,
#   'week52High': 90.76,
#   'week52Low': 57.18,
#   'ytdChange': 0.510312,
#   'lastTradeTime': 1567540648330,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALK',
#   'companyName': 'Alaska Air Group, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 59.43,
#   'openTime': 1567517400438,
#   'close': 60.43,
#   'closeTime': 1567483200000,
#   'high': 60.51,
#   'low': 59.43,
#   'latestPrice': 60.43,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1111128,
#   'iexRealtimePrice': 60.41,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794729,
#   'delayedPrice': 59.84,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 60.11,
#   'extendedChange': -0.32,
#   'extendedChangePercent': -0.0053,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 59.72,
#   'previousVolume': 842062,
#   'change': 0.71,
#   'changePercent': 0.01189,
#   'volume': 1111128,
#   'iexMarketPercent': 0.015398765938757731,
#   'iexVolume': 17110,
#   'avgTotalVolume': 1066975,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 7449326960,
#   'peRatio': 14.73,
#   'week52High': 74.83,
#   'week52Low': 53.38,
#   'ytdChange': -0.017369000000000002,
#   'lastTradeTime': 1567540794729,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALB',
#   'companyName': 'Albemarle Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 61,
#   'openTime': 1567517400468,
#   'close': 60.23,
#   'closeTime': 1567483200000,
#   'high': 61,
#   'low': 59.51,
#   'latestPrice': 60.23,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1372969,
#   'iexRealtimePrice': 60.25,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540791471,
#   'delayedPrice': 60.23,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 60.63,
#   'extendedChange': 0.4,
#   'extendedChangePercent': 0.00664,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 61.73,
#   'previousVolume': 1404335,
#   'change': -1.5,
#   'changePercent': -0.0243,
#   'volume': 1372969,
#   'iexMarketPercent': 0.04397113117630478,
#   'iexVolume': 60371,
#   'avgTotalVolume': 1642183,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 6383536780,
#   'peRatio': 11.7,
#   'week52High': 108.74,
#   'week52Low': 58.63,
#   'ytdChange': -0.234004,
#   'lastTradeTime': 1567540791471,
#   'isUSMarketOpen': False},
#  {'symbol': 'ARE',
#   'companyName': 'Alexandria Real Estate Equities, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 149.53,
#   'openTime': 1567517400410,
#   'close': 149.99,
#   'closeTime': 1567483200000,
#   'high': 150.52,
#   'low': 148.9,
#   'latestPrice': 149.99,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 552718,
#   'iexRealtimePrice': 149.99,
#   'iexRealtimeSize': 58,
#   'iexLastUpdated': 1567540788498,
#   'delayedPrice': 149.99,
#   'delayedPriceTime': 1567541400006,
#   'extendedPrice': 149.99,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800002,
#   'previousClose': 149.84,
#   'previousVolume': 728618,
#   'change': 0.15,
#   'changePercent': 0.001,
#   'volume': 552718,
#   'iexMarketPercent': 0.03435386580498554,
#   'iexVolume': 18988,
#   'avgTotalVolume': 633786,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 17011565820,
#   'peRatio': 42.8,
#   'week52High': 153.51,
#   'week52Low': 109.04,
#   'ytdChange': 0.346425,
#   'lastTradeTime': 1567540788498,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALXN',
#   'companyName': 'Alexion Pharmaceuticals, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 100.26,
#   'openTime': 1567517400300,
#   'close': 95.18,
#   'closeTime': 1567483200000,
#   'high': 100.38,
#   'low': 94.93,
#   'latestPrice': 95.18,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 6286640,
#   'iexRealtimePrice': 95.16,
#   'iexRealtimeSize': 99,
#   'iexLastUpdated': 1567540796177,
#   'delayedPrice': 95.18,
#   'delayedPriceTime': 1567540800554,
#   'extendedPrice': 95.18,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567552839487,
#   'previousClose': 100.76,
#   'previousVolume': 8547570,
#   'change': -5.58,
#   'changePercent': -0.05538,
#   'volume': 6286640,
#   'iexMarketPercent': 0.04005414657114134,
#   'iexVolume': 251806,
#   'avgTotalVolume': 2899021,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 21341925860,
#   'peRatio': 15.97,
#   'week52High': 141.86,
#   'week52Low': 92.56,
#   'ytdChange': -0.027741,
#   'lastTradeTime': 1567540426000,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALGN',
#   'companyName': 'Align Technology, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 182.23,
#   'openTime': 1567517400350,
#   'close': 177.91,
#   'closeTime': 1567483200000,
#   'high': 182.5,
#   'low': 177.25,
#   'latestPrice': 177.91,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1890515,
#   'iexRealtimePrice': 177.93,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540799402,
#   'delayedPrice': 177.91,
#   'delayedPriceTime': 1567540800391,
#   'extendedPrice': 177.5,
#   'extendedChange': -0.41,
#   'extendedChangePercent': -0.0023,
#   'extendedPriceTime': 1567552591355,
#   'previousClose': 183.11,
#   'previousVolume': 1679583,
#   'change': -5.2,
#   'changePercent': -0.0284,
#   'volume': 1890515,
#   'iexMarketPercent': 0.06208467005022441,
#   'iexVolume': 117372,
#   'avgTotalVolume': 1752290,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 14209849610,
#   'peRatio': 34.08,
#   'week52High': 398.87,
#   'week52Low': 172.11,
#   'ytdChange': -0.122453,
#   'lastTradeTime': 1567540713435,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALLE',
#   'companyName': 'Allegion Plc',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 95.73,
#   'openTime': 1567517400354,
#   'close': 95.33,
#   'closeTime': 1567483200000,
#   'high': 96.32,
#   'low': 94.72,
#   'latestPrice': 95.33,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 651115,
#   'iexRealtimePrice': 95.29,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540766510,
#   'delayedPrice': 95.33,
#   'delayedPriceTime': 1567541400012,
#   'extendedPrice': 95.33,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800012,
#   'previousClose': 96.27,
#   'previousVolume': 621455,
#   'change': -0.94,
#   'changePercent': -0.00976,
#   'volume': 651115,
#   'iexMarketPercent': 0.021827173387189668,
#   'iexVolume': 14212,
#   'avgTotalVolume': 774429,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 8901534080,
#   'peRatio': 20.57,
#   'week52High': 111.99,
#   'week52Low': 74.83,
#   'ytdChange': 0.17802500000000002,
#   'lastTradeTime': 1567540766510,
#   'isUSMarketOpen': False},
#  {'symbol': 'AGN',
#   'companyName': 'Allergan Plc',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 159.3,
#   'openTime': 1567517400373,
#   'close': 159.8,
#   'closeTime': 1567483200000,
#   'high': 160.19,
#   'low': 158.67,
#   'latestPrice': 159.8,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 4061315,
#   'iexRealtimePrice': 159.83,
#   'iexRealtimeSize': 3,
#   'iexLastUpdated': 1567540799944,
#   'delayedPrice': 159.8,
#   'delayedPriceTime': 1567541400000,
#   'extendedPrice': 159.8,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 159.72,
#   'previousVolume': 1948234,
#   'change': 0.08,
#   'changePercent': 0.0005,
#   'volume': 4061315,
#   'iexMarketPercent': 0.01308763294647177,
#   'iexVolume': 53153,
#   'avgTotalVolume': 4102946,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 52419673400,
#   'peRatio': -6.25,
#   'week52High': 197,
#   'week52Low': 114.27,
#   'ytdChange': 0.175949,
#   'lastTradeTime': 1567540790866,
#   'isUSMarketOpen': False},
#  {'symbol': 'ADS',
#   'companyName': 'Alliance Data Systems Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 122.73,
#   'openTime': 1567517400396,
#   'close': 122.05,
#   'closeTime': 1567483200000,
#   'high': 122.73,
#   'low': 118.4,
#   'latestPrice': 122.05,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1475944,
#   'iexRealtimePrice': 122.12,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540786646,
#   'delayedPrice': 122.05,
#   'delayedPriceTime': 1567541400000,
#   'extendedPrice': 122.05,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800010,
#   'previousClose': 122.32000000000001,
#   'previousVolume': 709172,
#   'change': -0.27,
#   'changePercent': -0.00732,
#   'volume': 1475944,
#   'iexMarketPercent': 0.024237369439490928,
#   'iexVolume': 35773,
#   'avgTotalVolume': 1349080,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 6236510900,
#   'peRatio': 7.53,
#   'week52High': 250.27,
#   'week52Low': 120.77,
#   'ytdChange': -0.216034,
#   'lastTradeTime': 1567540786646,
#   'isUSMarketOpen': False},
#  {'symbol': 'LNT',
#   'companyName': 'Alliant Energy Corp.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 52.75,
#   'openTime': 1567517400810,
#   'close': 53.56,
#   'closeTime': 1567483200000,
#   'high': 53.81,
#   'low': 52.48,
#   'latestPrice': 53.56,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2265745,
#   'iexRealtimePrice': 53.56,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540789959,
#   'delayedPrice': 53.56,
#   'delayedPriceTime': 1567540800536,
#   'extendedPrice': 53.56,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567545211114,
#   'previousClose': 52.45,
#   'previousVolume': 1592648,
#   'change': 1.11,
#   'changePercent': 0.02116,
#   'volume': 2265745,
#   'iexMarketPercent': 0.03265945638189646,
#   'iexVolume': 73998,
#   'avgTotalVolume': 1180825,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 12721624760,
#   'peRatio': 24.77,
#   'week52High': 53.56,
#   'week52Low': 40.68,
#   'ytdChange': 0.295765,
#   'lastTradeTime': 1567540707517,
#   'isUSMarketOpen': False},
#  {'symbol': 'ALL',
#   'companyName': 'The Allstate Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 101.81,
#   'openTime': 1567517400421,
#   'close': 102.54,
#   'closeTime': 1567483200000,
#   'high': 102.74,
#   'low': 101.61,
#   'latestPrice': 102.54,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1970494,
#   'iexRealtimePrice': 102.54,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540791006,
#   'delayedPrice': 102.54,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 102.54,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 102.39,
#   'previousVolume': 2077847,
#   'change': 0.15,
#   'changePercent': 0.00146,
#   'volume': 1970494,
#   'iexMarketPercent': 0.005317955801946111,
#   'iexVolume': 10479,
#   'avgTotalVolume': 1547179,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 33755347680,
#   'peRatio': 13.21,
#   'week52High': 109.13,
#   'week52Low': 77,
#   'ytdChange': 0.255625,
#   'lastTradeTime': 1567540791006,
#   'isUSMarketOpen': False},
#  {'symbol': 'GOOGL',
#   'companyName': 'Alphabet, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 1181.85,
#   'openTime': 1567517400401,
#   'close': 1169.55,
#   'closeTime': 1567483200000,
#   'high': 1189.08,
#   'low': 1163.715,
#   'latestPrice': 1169.55,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1296595,
#   'iexRealtimePrice': 1169.68,
#   'iexRealtimeSize': 9,
#   'iexLastUpdated': 1567540799207,
#   'delayedPrice': 1169.55,
#   'delayedPriceTime': 1567540800459,
#   'extendedPrice': 1171.1,
#   'extendedChange': 1.55,
#   'extendedChangePercent': 0.00133,
#   'extendedPriceTime': 1567551360913,
#   'previousClose': 1190.53,
#   'previousVolume': 903375,
#   'change': -20.98,
#   'changePercent': -0.01762,
#   'volume': 1296595,
#   'iexMarketPercent': 0.03556391934258577,
#   'iexVolume': 46112,
#   'avgTotalVolume': 1577941,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 810990862702,
#   'peRatio': 23.39,
#   'week52High': 1296.97,
#   'week52Low': 977.65,
#   'ytdChange': 0.11118700000000001,
#   'lastTradeTime': 1567540785038,
#   'isUSMarketOpen': False},
#  {'symbol': 'GOOG',
#   'companyName': 'Alphabet, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 1177.03,
#   'openTime': 1567517400782,
#   'close': 1168.39,
#   'closeTime': 1567483200000,
#   'high': 1186.89,
#   'low': 1163.2,
#   'latestPrice': 1168.39,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1480874,
#   'iexRealtimePrice': 1168.95,
#   'iexRealtimeSize': 3,
#   'iexLastUpdated': 1567540798974,
#   'delayedPrice': 1168.39,
#   'delayedPriceTime': 1567540800303,
#   'extendedPrice': 1169.09,
#   'extendedChange': 0.7,
#   'extendedChangePercent': 0.0006,
#   'extendedPriceTime': 1567554248383,
#   'previousClose': 1188.1,
#   'previousVolume': 1129959,
#   'change': -19.71,
#   'changePercent': -0.01659,
#   'volume': 1480874,
#   'iexMarketPercent': 0.03023079613795637,
#   'iexVolume': 44768,
#   'avgTotalVolume': 1517832,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 810186494013,
#   'peRatio': 23.37,
#   'week52High': 1289.27,
#   'week52Low': 970.11,
#   'ytdChange': 0.119424,
#   'lastTradeTime': 1567540759615,
#   'isUSMarketOpen': False},
#  {'symbol': 'MO',
#   'companyName': 'Altria Group, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 43.7,
#   'openTime': 1567517425690,
#   'close': 44.04,
#   'closeTime': 1567483200000,
#   'high': 44.14,
#   'low': 43.07,
#   'latestPrice': 44.04,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 8941972,
#   'iexRealtimePrice': 44.05,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540797959,
#   'delayedPrice': 44.09,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 44.08,
#   'extendedChange': 0.04,
#   'extendedChangePercent': 0.00091,
#   'extendedPriceTime': 1567551006854,
#   'previousClose': 43.74,
#   'previousVolume': 13985341,
#   'change': 0.3,
#   'changePercent': 0.00686,
#   'volume': 8941972,
#   'iexMarketPercent': 0.06085671035427085,
#   'iexVolume': 544179,
#   'avgTotalVolume': 10698624,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 82271124000,
#   'peRatio': 13.07,
#   'week52High': 66.04,
#   'week52Low': 42.4,
#   'ytdChange': -0.106099,
#   'lastTradeTime': 1567540797959,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMZN',
#   'companyName': 'Amazon.com, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 1771.02,
#   'openTime': 1567517400650,
#   'close': 1789.84,
#   'closeTime': 1567483200000,
#   'high': 1800.8,
#   'low': 1768,
#   'latestPrice': 1789.84,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 3543731,
#   'iexRealtimePrice': 1790.7,
#   'iexRealtimeSize': 3,
#   'iexLastUpdated': 1567540791864,
#   'delayedPrice': 1788.5,
#   'delayedPriceTime': 1567541700009,
#   'extendedPrice': 1789.42,
#   'extendedChange': -0.42,
#   'extendedChangePercent': -0.00023,
#   'extendedPriceTime': 1567554286730,
#   'previousClose': 1776.29,
#   'previousVolume': 3064147,
#   'change': 13.55,
#   'changePercent': 0.00763,
#   'volume': 3543731,
#   'iexMarketPercent': 0.0313251767699072,
#   'iexVolume': 111008,
#   'avgTotalVolume': 3660319,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 885355095040,
#   'peRatio': 72.56,
#   'week52High': 2050.5,
#   'week52Low': 1307,
#   'ytdChange': 0.161717,
#   'lastTradeTime': 1567534626601,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMCR',
#   'companyName': 'Amcor Plc',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 9.84,
#   'openTime': 1567517488374,
#   'close': 9.71,
#   'closeTime': 1567483200000,
#   'high': 9.85,
#   'low': 9.65,
#   'latestPrice': 9.71,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 3927295,
#   'iexRealtimePrice': 9.705,
#   'iexRealtimeSize': 195,
#   'iexLastUpdated': 1567540797706,
#   'delayedPrice': 9.71,
#   'delayedPriceTime': 1567541400005,
#   'extendedPrice': 9.71,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800009,
#   'previousClose': 9.82,
#   'previousVolume': 3963166,
#   'change': -0.11,
#   'changePercent': -0.0112,
#   'volume': 3927295,
#   'iexMarketPercent': 0.07662653302081968,
#   'iexVolume': 300935,
#   'avgTotalVolume': 4597354,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 15764476300,
#   'peRatio': 16.98,
#   'week52High': 11.77,
#   'week52Low': 9.32,
#   'ytdChange': -0.132846,
#   'lastTradeTime': 1567540797706,
#   'isUSMarketOpen': False},
#  {'symbol': 'AEE',
#   'companyName': 'Ameren Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 77.22,
#   'openTime': 1567517400413,
#   'close': 78.49,
#   'closeTime': 1567483200000,
#   'high': 78.51,
#   'low': 76.96,
#   'latestPrice': 78.49,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2381309,
#   'iexRealtimePrice': 78.43,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540755610,
#   'delayedPrice': 78.49,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 78.49,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 77.15,
#   'previousVolume': 1961396,
#   'change': 1.34,
#   'changePercent': 0.01737,
#   'volume': 2381309,
#   'iexMarketPercent': 0.022715657648797363,
#   'iexVolume': 54093,
#   'avgTotalVolume': 1953263,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 19293077470,
#   'peRatio': 24.17,
#   'week52High': 78.49,
#   'week52Low': 62.05,
#   'ytdChange': 0.231757,
#   'lastTradeTime': 1567540755610,
#   'isUSMarketOpen': False},
#  {'symbol': 'AAL',
#   'companyName': 'American Airlines Group, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 26.16,
#   'openTime': 1567517401057,
#   'close': 26.51,
#   'closeTime': 1567483200000,
#   'high': 26.66,
#   'low': 25.95,
#   'latestPrice': 26.51,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 6731619,
#   'iexRealtimePrice': 26.53,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540787824,
#   'delayedPrice': 26.51,
#   'delayedPriceTime': 1567540800377,
#   'extendedPrice': 26.43,
#   'extendedChange': -0.08,
#   'extendedChangePercent': -0.00302,
#   'extendedPriceTime': 1567551156190,
#   'previousClose': 26.31,
#   'previousVolume': 5076364,
#   'change': 0.2,
#   'changePercent': 0.0076,
#   'volume': 6731619,
#   'iexMarketPercent': 0.01952695183729204,
#   'iexVolume': 131448,
#   'avgTotalVolume': 7563663,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 11804134210,
#   'peRatio': 7.96,
#   'week52High': 43.89,
#   'week52Low': 24.23,
#   'ytdChange': -0.182363,
#   'lastTradeTime': 1567540659695,
#   'isUSMarketOpen': False},
#  {'symbol': 'AEP',
#   'companyName': 'American Electric Power Co., Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 91.22,
#   'openTime': 1567517400459,
#   'close': 92.78,
#   'closeTime': 1567483200000,
#   'high': 92.87,
#   'low': 90.98,
#   'latestPrice': 92.78,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1946618,
#   'iexRealtimePrice': 92.79,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540796701,
#   'delayedPrice': 92.78,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 92.78,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 91.15,
#   'previousVolume': 2584678,
#   'change': 1.63,
#   'changePercent': 0.01788,
#   'volume': 1946618,
#   'iexMarketPercent': 0.03470480597631379,
#   'iexVolume': 67557,
#   'avgTotalVolume': 2251817,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 45814300100,
#   'peRatio': 23.17,
#   'week52High': 92.78,
#   'week52Low': 68.92,
#   'ytdChange': 0.26753699999999997,
#   'lastTradeTime': 1567540796701,
#   'isUSMarketOpen': False},
#  {'symbol': 'AXP',
#   'companyName': 'American Express Co.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 119.63,
#   'openTime': 1567517497156,
#   'close': 117.6,
#   'closeTime': 1567483200000,
#   'high': 120.28,
#   'low': 117.52,
#   'latestPrice': 117.6,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 3231612,
#   'iexRealtimePrice': 117.6,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540795010,
#   'delayedPrice': 117.6,
#   'delayedPriceTime': 1567541400006,
#   'extendedPrice': 117.6,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567551950293,
#   'previousClose': 120.37,
#   'previousVolume': 2366225,
#   'change': -2.77,
#   'changePercent': -0.02301,
#   'volume': 3231612,
#   'iexMarketPercent': 0.037907397298933165,
#   'iexVolume': 122502,
#   'avgTotalVolume': 3229220,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 97569662400,
#   'peRatio': 14.53,
#   'week52High': 129.34,
#   'week52Low': 89.05,
#   'ytdChange': 0.235038,
#   'lastTradeTime': 1567540795010,
#   'isUSMarketOpen': False},
#  {'symbol': 'AIG',
#   'companyName': 'American International Group, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 51.75,
#   'openTime': 1567517400462,
#   'close': 52.4,
#   'closeTime': 1567483200000,
#   'high': 52.49,
#   'low': 51.65,
#   'latestPrice': 52.4,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2901247,
#   'iexRealtimePrice': 52.39,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794966,
#   'delayedPrice': 52.4,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 52.4,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 52.04,
#   'previousVolume': 4565049,
#   'change': 0.36,
#   'changePercent': 0.00692,
#   'volume': 2901247,
#   'iexMarketPercent': 0.0369337736497444,
#   'iexVolume': 107154,
#   'avgTotalVolume': 3673322,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 45583179200,
#   'peRatio': -524,
#   'week52High': 57.58,
#   'week52Low': 36.16,
#   'ytdChange': 0.32039799999999996,
#   'lastTradeTime': 1567540794966,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMT',
#   'companyName': 'American Tower Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 230.6,
#   'openTime': 1567517400531,
#   'close': 237.84,
#   'closeTime': 1567483200000,
#   'high': 237.9,
#   'low': 230.19,
#   'latestPrice': 237.84,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1843305,
#   'iexRealtimePrice': 237.88,
#   'iexRealtimeSize': 29,
#   'iexLastUpdated': 1567540795142,
#   'delayedPrice': 237.8,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 238.7,
#   'extendedChange': 0.86,
#   'extendedChangePercent': 0.00362,
#   'extendedPriceTime': 1567552990027,
#   'previousClose': 230.19,
#   'previousVolume': 1426204,
#   'change': 7.65,
#   'changePercent': 0.03323,
#   'volume': 1843305,
#   'iexMarketPercent': 0.027477275871328945,
#   'iexVolume': 50649,
#   'avgTotalVolume': 1608595,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 105288200400,
#   'peRatio': 71.42,
#   'week52High': 237.84,
#   'week52Low': 140.39,
#   'ytdChange': 0.5018400000000001,
#   'lastTradeTime': 1567540795142,
#   'isUSMarketOpen': False},
#  {'symbol': 'AWK',
#   'companyName': 'American Water Works Co., Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 128.36,
#   'openTime': 1567517400406,
#   'close': 129.5,
#   'closeTime': 1567483200000,
#   'high': 129.6,
#   'low': 127.34,
#   'latestPrice': 129.5,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1096732,
#   'iexRealtimePrice': 129.49,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794013,
#   'delayedPrice': 129.5,
#   'delayedPriceTime': 1567541400011,
#   'extendedPrice': 125,
#   'extendedChange': -4.5,
#   'extendedChangePercent': -0.03475,
#   'extendedPriceTime': 1567549800009,
#   'previousClose': 127.32,
#   'previousVolume': 790173,
#   'change': 2.18,
#   'changePercent': 0.01712,
#   'volume': 1096732,
#   'iexMarketPercent': 0.03321048350918912,
#   'iexVolume': 36423,
#   'avgTotalVolume': 919032,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 23394563500,
#   'peRatio': 40.3,
#   'week52High': 129.5,
#   'week52Low': 85.88,
#   'ytdChange': 0.451388,
#   'lastTradeTime': 1567540794013,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMP',
#   'companyName': 'Ameriprise Financial, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 127.31,
#   'openTime': 1567517517954,
#   'close': 127.2,
#   'closeTime': 1567483200000,
#   'high': 128.74,
#   'low': 125.86,
#   'latestPrice': 127.2,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1011535,
#   'iexRealtimePrice': 127.2,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540765451,
#   'delayedPrice': 127.2,
#   'delayedPriceTime': 1567541400002,
#   'extendedPrice': 127.2,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 128.98,
#   'previousVolume': 668362,
#   'change': -1.78,
#   'changePercent': -0.0138,
#   'volume': 1011535,
#   'iexMarketPercent': 0.039085152762880174,
#   'iexVolume': 39536,
#   'avgTotalVolume': 1117593,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 16646664000,
#   'peRatio': 9.25,
#   'week52High': 153.91,
#   'week52Low': 95.69,
#   'ytdChange': 0.18090199999999998,
#   'lastTradeTime': 1567540765451,
#   'isUSMarketOpen': False},
#  {'symbol': 'ABC',
#   'companyName': 'AmerisourceBergen Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 81.87,
#   'openTime': 1567517400419,
#   'close': 84.04,
#   'closeTime': 1567483200000,
#   'high': 84.5,
#   'low': 81.555,
#   'latestPrice': 84.04,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1614705,
#   'iexRealtimePrice': 83.97,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540779677,
#   'delayedPrice': 84.04,
#   'delayedPriceTime': 1567541400004,
#   'extendedPrice': 84.04,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 82.27,
#   'previousVolume': 1092038,
#   'change': 1.77,
#   'changePercent': 0.02151,
#   'volume': 1614705,
#   'iexMarketPercent': 0.032797322111469275,
#   'iexVolume': 52958,
#   'avgTotalVolume': 1364015,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 17507717040,
#   'peRatio': 18.63,
#   'week52High': 94.85,
#   'week52Low': 69.36,
#   'ytdChange': 0.12654700000000002,
#   'lastTradeTime': 1567540779677,
#   'isUSMarketOpen': False},
#  {'symbol': 'AME',
#   'companyName': 'AMETEK, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 85.07,
#   'openTime': 1567517400427,
#   'close': 83.38,
#   'closeTime': 1567483200000,
#   'high': 85.53,
#   'low': 82.76,
#   'latestPrice': 83.38,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 906345,
#   'iexRealtimePrice': 83.41,
#   'iexRealtimeSize': 53,
#   'iexLastUpdated': 1567540776368,
#   'delayedPrice': 83.38,
#   'delayedPriceTime': 1567541400003,
#   'extendedPrice': 83.38,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800003,
#   'previousClose': 85.93,
#   'previousVolume': 1052042,
#   'change': -2.55,
#   'changePercent': -0.02968,
#   'volume': 906345,
#   'iexMarketPercent': 0.058808731774324344,
#   'iexVolume': 53301,
#   'avgTotalVolume': 1176299,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 19039489480,
#   'peRatio': 23.2,
#   'week52High': 92.3,
#   'week52Low': 63.14,
#   'ytdChange': 0.243546,
#   'lastTradeTime': 1567540776368,
#   'isUSMarketOpen': False},
#  {'symbol': 'AMGN',
#   'companyName': 'Amgen, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 207.3,
#   'openTime': 1567517400908,
#   'close': 205.52,
#   'closeTime': 1567483200000,
#   'high': 207.885,
#   'low': 204.68,
#   'latestPrice': 205.52,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2195545,
#   'iexRealtimePrice': 205.56,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540799179,
#   'delayedPrice': 205.52,
#   'delayedPriceTime': 1567540800480,
#   'extendedPrice': 205.45,
#   'extendedChange': -0.07,
#   'extendedChangePercent': -0.00034,
#   'extendedPriceTime': 1567547331881,
#   'previousClose': 208.62,
#   'previousVolume': 2621349,
#   'change': -3.1,
#   'changePercent': -0.01486,
#   'volume': 2195545,
#   'iexMarketPercent': 0.03141087975878427,
#   'iexVolume': 68964,
#   'avgTotalVolume': 3567449,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 123250549520,
#   'peRatio': 16.17,
#   'week52High': 211.9,
#   'week52Low': 166.3,
#   'ytdChange': 0.072269,
#   'lastTradeTime': 1567538768986,
#   'isUSMarketOpen': False},
#  {'symbol': 'APH',
#   'companyName': 'Amphenol Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 86.33,
#   'openTime': 1567517400430,
#   'close': 85.69,
#   'closeTime': 1567483200000,
#   'high': 86.684,
#   'low': 85.36,
#   'latestPrice': 85.69,
#   'latestSource': 'Close',
# ...
#   'high': 33.85,
#   'low': 32.89,
#   'latestPrice': 33.01,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2076052,
#   'iexRealtimePrice': 32.985,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540780794,
#   'delayedPrice': 33.01,
#   'delayedPriceTime': 1567541400013,
#   'extendedPrice': 33.01,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800002,
#   'previousClose': 34.18,
#   'previousVolume': 1863604,
#   'change': -1.17,
#   'changePercent': -0.03423,
#   'volume': 2076052,
#   'iexMarketPercent': 0.04248207655684925,
#   'iexVolume': 88195,
#   'avgTotalVolume': 2183506,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 8494859420,
#   'peRatio': 10.14,
#   'week52High': 57.23,
#   'week52Low': 31.94,
#   'ytdChange': -0.155341,
#   'lastTradeTime': 1567540780794,
#   'isUSMarketOpen': False},
#  {'symbol': 'WY',
#   'companyName': 'Weyerhaeuser Co.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 26.19,
#   'openTime': 1567517400355,
#   'close': 26.4,
#   'closeTime': 1567483200000,
#   'high': 26.42,
#   'low': 26.03,
#   'latestPrice': 26.4,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2833694,
#   'iexRealtimePrice': 26.4,
#   'iexRealtimeSize': 13,
#   'iexLastUpdated': 1567540795020,
#   'delayedPrice': 26.4,
#   'delayedPriceTime': 1567541400009,
#   'extendedPrice': 26.2,
#   'extendedChange': -0.2,
#   'extendedChangePercent': -0.00758,
#   'extendedPriceTime': 1567549800007,
#   'previousClose': 26.31,
#   'previousVolume': 4557895,
#   'change': 0.09,
#   'changePercent': 0.00342,
#   'volume': 2833694,
#   'iexMarketPercent': 0.02641675494954642,
#   'iexVolume': 74857,
#   'avgTotalVolume': 3535004,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 19666125600,
#   'peRatio': 5739.13,
#   'week52High': 34.8,
#   'week52Low': 20.52,
#   'ytdChange': 0.225436,
#   'lastTradeTime': 1567540795020,
#   'isUSMarketOpen': False},
#  {'symbol': 'WHR',
#   'companyName': 'Whirlpool Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 137,
#   'openTime': 1567517626222,
#   'close': 134.47,
#   'closeTime': 1567483200000,
#   'high': 138.47,
#   'low': 133.06,
#   'latestPrice': 134.47,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 575011,
#   'iexRealtimePrice': 134.5,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794629,
#   'delayedPrice': 134.47,
#   'delayedPriceTime': 1567541400000,
#   'extendedPrice': 134.47,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800001,
#   'previousClose': 139.09,
#   'previousVolume': 556076,
#   'change': -4.62,
#   'changePercent': -0.03322,
#   'volume': 575011,
#   'iexMarketPercent': 0.060531015928390934,
#   'iexVolume': 34806,
#   'avgTotalVolume': 735597,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 8542475690,
#   'peRatio': 9.39,
#   'week52High': 152.5,
#   'week52Low': 99.4,
#   'ytdChange': 0.25560499999999997,
#   'lastTradeTime': 1567540794629,
#   'isUSMarketOpen': False},
#  {'symbol': 'WMB',
#   'companyName': 'The Williams Cos., Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 23.4,
#   'openTime': 1567517400359,
#   'close': 23.55,
#   'closeTime': 1567483200000,
#   'high': 23.6,
#   'low': 23.22,
#   'latestPrice': 23.55,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 4501529,
#   'iexRealtimePrice': 23.535,
#   'iexRealtimeSize': 300,
#   'iexLastUpdated': 1567540789802,
#   'delayedPrice': 23.55,
#   'delayedPriceTime': 1567541400000,
#   'extendedPrice': 23.55,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800001,
#   'previousClose': 23.6,
#   'previousVolume': 5842845,
#   'change': -0.05,
#   'changePercent': -0.00212,
#   'volume': 4501529,
#   'iexMarketPercent': 0.05995362908913838,
#   'iexVolume': 269883,
#   'avgTotalVolume': 9564041,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 28543071000,
#   'peRatio': 310.28,
#   'week52High': 29.65,
#   'week52Low': 20.36,
#   'ytdChange': 0.050512,
#   'lastTradeTime': 1567540789802,
#   'isUSMarketOpen': False},
#  {'symbol': 'WLTW',
#   'companyName': 'Willis Towers Watson Plc',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 197.3,
#   'openTime': 1567517400849,
#   'close': 195.66,
#   'closeTime': 1567483200000,
#   'high': 197.98,
#   'low': 194.72,
#   'latestPrice': 195.66,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 502714,
#   'iexRealtimePrice': 195.67,
#   'iexRealtimeSize': 38,
#   'iexLastUpdated': 1567540782118,
#   'delayedPrice': 195.66,
#   'delayedPriceTime': 1567540800559,
#   'extendedPrice': 195.66,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567545210831,
#   'previousClose': 197.97,
#   'previousVolume': 649582,
#   'change': -2.31,
#   'changePercent': -0.01167,
#   'volume': 502714,
#   'iexMarketPercent': 0.026989500988633695,
#   'iexVolume': 13568,
#   'avgTotalVolume': 657467,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 25238966040,
#   'peRatio': 30.04,
#   'week52High': 200.93,
#   'week52Low': 134.5,
#   'ytdChange': 0.310952,
#   'lastTradeTime': 1567540505076,
#   'isUSMarketOpen': False},
#  {'symbol': 'WYNN',
#   'companyName': 'Wynn Resorts Ltd.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 106.56,
#   'openTime': 1567517400460,
#   'close': 105.33,
#   'closeTime': 1567483200000,
#   'high': 107.22,
#   'low': 104.265,
#   'latestPrice': 105.33,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2395463,
#   'iexRealtimePrice': 105.39,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794219,
#   'delayedPrice': 105.33,
#   'delayedPriceTime': 1567540800254,
#   'extendedPrice': 105.39,
#   'extendedChange': 0.06,
#   'extendedChangePercent': 0.00057,
#   'extendedPriceTime': 1567547978298,
#   'previousClose': 110.15,
#   'previousVolume': 2685571,
#   'change': -4.82,
#   'changePercent': -0.04376,
#   'volume': 2395463,
#   'iexMarketPercent': 0.02573907424159755,
#   'iexVolume': 61657,
#   'avgTotalVolume': 2307151,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 11335193280,
#   'peRatio': 13.63,
#   'week52High': 151.5,
#   'week52Low': 90.06,
#   'ytdChange': 0.011317,
#   'lastTradeTime': 1567540794219,
#   'isUSMarketOpen': False},
#  {'symbol': 'XEL',
#   'companyName': 'Xcel Energy, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 64.34,
#   'openTime': 1567517400706,
#   'close': 65.53,
#   'closeTime': 1567483200000,
#   'high': 65.57,
#   'low': 64.22,
#   'latestPrice': 65.53,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2930915,
#   'iexRealtimePrice': 65.555,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794013,
#   'delayedPrice': 65.53,
#   'delayedPriceTime': 1567540800300,
#   'extendedPrice': 65.5,
#   'extendedChange': -0.03,
#   'extendedChangePercent': -0.00046,
#   'extendedPriceTime': 1567545672729,
#   'previousClose': 64.22,
#   'previousVolume': 3193797,
#   'change': 1.31,
#   'changePercent': 0.0204,
#   'volume': 2930915,
#   'iexMarketPercent': 0.022196140113241086,
#   'iexVolume': 65055,
#   'avgTotalVolume': 3427971,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 33748670830,
#   'peRatio': 26.75,
#   'week52High': 65.53,
#   'week52Low': 46.01,
#   'ytdChange': 0.352213,
#   'lastTradeTime': 1567540711009,
#   'isUSMarketOpen': False},
#  {'symbol': 'XRX',
#   'companyName': 'Xerox Holdings Corp.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 28.6,
#   'openTime': 1567517400358,
#   'close': 29.11,
#   'closeTime': 1567483200000,
#   'high': 29.21,
#   'low': 28.54,
#   'latestPrice': 29.11,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2433023,
#   'iexRealtimePrice': 29.12,
#   'iexRealtimeSize': 300,
#   'iexLastUpdated': 1567540790226,
#   'delayedPrice': 29.11,
#   'delayedPriceTime': 1567541400008,
#   'extendedPrice': 29.11,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800007,
#   'previousClose': 28.99,
#   'previousVolume': 2053639,
#   'change': 0.12,
#   'changePercent': 0.00414,
#   'volume': 2433023,
#   'iexMarketPercent': 0.02827059176999149,
#   'iexVolume': 68783,
#   'avgTotalVolume': 2361495,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 6441577240,
#   'peRatio': 12.84,
#   'week52High': 36.57,
#   'week52Low': 18.57,
#   'ytdChange': 0.444279,
#   'lastTradeTime': 1567540790226,
#   'isUSMarketOpen': False},
#  {'symbol': 'XLNX',
#   'companyName': 'Xilinx, Inc.',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 102.66,
#   'openTime': 1567517401031,
#   'close': 100.4,
#   'closeTime': 1567483200000,
#   'high': 103.18,
#   'low': 99.81,
#   'latestPrice': 100.4,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 3218488,
#   'iexRealtimePrice': 100.37,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540787653,
#   'delayedPrice': 100.4,
#   'delayedPriceTime': 1567540800578,
#   'extendedPrice': 100.4,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567552456649,
#   'previousClose': 104.06,
#   'previousVolume': 1938788,
#   'change': -3.66,
#   'changePercent': -0.03517,
#   'volume': 3218488,
#   'iexMarketPercent': 0.03397682389991822,
#   'iexVolume': 109354,
#   'avgTotalVolume': 3509289,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 25361542000,
#   'peRatio': 27.01,
#   'week52High': 141.6,
#   'week52Low': 68.76,
#   'ytdChange': 0.162988,
#   'lastTradeTime': 1567540644410,
#   'isUSMarketOpen': False},
#  {'symbol': 'XYL',
#   'companyName': 'Xylem, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 75.84,
#   'openTime': 1567517400394,
#   'close': 74.64,
#   'closeTime': 1567483200000,
#   'high': 76.25,
#   'low': 74.08,
#   'latestPrice': 74.64,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 709474,
#   'iexRealtimePrice': 74.62,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794977,
#   'delayedPrice': 74.64,
#   'delayedPriceTime': 1567541400012,
#   'extendedPrice': 74.64,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800012,
#   'previousClose': 76.61,
#   'previousVolume': 637587,
#   'change': -1.97,
#   'changePercent': -0.02571,
#   'volume': 709474,
#   'iexMarketPercent': 0.02380073124596532,
#   'iexVolume': 16886,
#   'avgTotalVolume': 719491,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 13437364560,
#   'peRatio': 23.43,
#   'week52High': 85.39,
#   'week52Low': 60.65,
#   'ytdChange': 0.12614699999999998,
#   'lastTradeTime': 1567540794977,
#   'isUSMarketOpen': False},
#  {'symbol': 'YUM',
#   'companyName': 'Yum! Brands, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 116.8,
#   'openTime': 1567517400354,
#   'close': 116.71,
#   'closeTime': 1567483200000,
#   'high': 117.49,
#   'low': 116.28,
#   'latestPrice': 116.71,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1365339,
#   'iexRealtimePrice': 116.74,
#   'iexRealtimeSize': 2,
#   'iexLastUpdated': 1567540764112,
#   'delayedPrice': 116.71,
#   'delayedPriceTime': 1567541400007,
#   'extendedPrice': 116.71,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800007,
#   'previousClose': 116.78,
#   'previousVolume': 1154468,
#   'change': -0.07,
#   'changePercent': -0.0006,
#   'volume': 1365339,
#   'iexMarketPercent': 0.018780683771576143,
#   'iexVolume': 25642,
#   'avgTotalVolume': 1399361,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 35513219060,
#   'peRatio': 27.22,
#   'week52High': 119.72,
#   'week52Low': 84.53,
#   'ytdChange': 0.276522,
#   'lastTradeTime': 1567540764112,
#   'isUSMarketOpen': False},
#  {'symbol': 'ZBH',
#   'companyName': 'Zimmer Biomet Holdings, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 138.16,
#   'openTime': 1567517400369,
#   'close': 139.39,
#   'closeTime': 1567483200000,
#   'high': 139.72,
#   'low': 137.9,
#   'latestPrice': 139.39,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 873249,
#   'iexRealtimePrice': 139.38,
#   'iexRealtimeSize': 1,
#   'iexLastUpdated': 1567540782012,
#   'delayedPrice': 139.39,
#   'delayedPriceTime': 1567541400007,
#   'extendedPrice': 139.39,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800008,
#   'previousClose': 139.2,
#   'previousVolume': 1025677,
#   'change': 0.19,
#   'changePercent': 0.00136,
#   'volume': 873249,
#   'iexMarketPercent': 0.035322113165889686,
#   'iexVolume': 30845,
#   'avgTotalVolume': 1332038,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 28618857850,
#   'peRatio': -79.19,
#   'week52High': 140.53,
#   'week52Low': 96.99,
#   'ytdChange': 0.36233000000000004,
#   'lastTradeTime': 1567540782012,
#   'isUSMarketOpen': False},
#  {'symbol': 'ZION',
#   'companyName': 'Zions Bancorporation NA',
#   'primaryExchange': 'NASDAQ',
#   'calculationPrice': 'close',
#   'open': 40.78,
#   'openTime': 1567517400074,
#   'close': 39.79,
#   'closeTime': 1567483200000,
#   'high': 40.78,
#   'low': 39.74,
#   'latestPrice': 39.79,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 2581419,
#   'iexRealtimePrice': 39.785,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540794297,
#   'delayedPrice': 39.79,
#   'delayedPriceTime': 1567540800768,
#   'extendedPrice': 39.79,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567545210696,
#   'previousClose': 41.09,
#   'previousVolume': 1490782,
#   'change': -1.3,
#   'changePercent': -0.03164,
#   'volume': 2581419,
#   'iexMarketPercent': 0.06829732019482308,
#   'iexVolume': 176304,
#   'avgTotalVolume': 2851524,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 7041357770,
#   'peRatio': 9.07,
#   'week52High': 54.37,
#   'week52Low': 38.08,
#   'ytdChange': -0.043425000000000005,
#   'lastTradeTime': 1567540167532,
#   'isUSMarketOpen': False},
#  {'symbol': 'ZTS',
#   'companyName': 'Zoetis, Inc.',
#   'primaryExchange': 'New York Stock Exchange',
#   'calculationPrice': 'close',
#   'open': 126.13,
#   'openTime': 1567517400424,
#   'close': 127.04,
#   'closeTime': 1567483200000,
#   'high': 127.45,
#   'low': 125.98,
#   'latestPrice': 127.04,
#   'latestSource': 'Close',
#   'latestTime': 'September 3, 2019',
#   'latestUpdate': 1567483200000,
#   'latestVolume': 1891376,
#   'iexRealtimePrice': 127.08,
#   'iexRealtimeSize': 100,
#   'iexLastUpdated': 1567540799028,
#   'delayedPrice': 127.04,
#   'delayedPriceTime': 1567541400013,
#   'extendedPrice': 127.04,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1567549800013,
#   'previousClose': 126.42,
#   'previousVolume': 1601187,
#   'change': 0.62,
#   'changePercent': 0.0049,
#   'volume': 1891376,
#   'iexMarketPercent': 0.03134331830371116,
#   'iexVolume': 59282,
#   'avgTotalVolume': 1872588,
#   'iexBidPrice': 0,
#   'iexBidSize': 0,
#   'iexAskPrice': 0,
#   'iexAskSize': 0,
#   'marketCap': 60668968320,
#   'peRatio': 44.37,
#   'week52High': 128.41,
#   'week52Low': 78.9,
#   'ytdChange': 0.5013489999999999,
#   'lastTradeTime': 1567540799028,
#   'isUSMarketOpen': False}]

# %%
stocks_data[0]
stock_data_df = pd.DataFrame(stocks_data)
stock_data_df.to_csv("stocks_data/stock_data_fortune500.csv", index=False, encoding='utf8')

# %%
stock_data_df
# Out:
#      avgTotalVolume calculationPrice  change  changePercent    close  \
# 0           3000058            close   -3.08       -0.01905   158.64
# 1           4573684            close   -1.26       -0.01477    84.06
# 2           9090799            close   -0.34       -0.00517    65.40
# 3            716532            close   -9.43       -0.04884   183.64
# 4           1724995            close   -2.42       -0.01221   195.75
# 5           7000154            close    0.46        0.00909    51.06
# 6           2231047            close   -2.06       -0.00724   282.45
# 7          69530176            close   -0.55       -0.01749    30.90
# 8           1423485            close    2.41        0.01747   140.36
# 9           5118649            close    0.01        0.00065    15.34
# 10           544172            close   -1.66       -0.02166    74.97
# 11          3681345            close    0.20        0.00399    50.38
# 12          2615599            close   -0.70       -0.00984    70.41
# 13           998370            close   -0.36       -0.00159   225.56
# 14          1750220            close   -0.01       -0.00011    89.12
# 15          1066975            close    0.71        0.01189    60.43
# 16          1642183            close   -1.50       -0.02430    60.23
# 17           633786            close    0.15        0.00100   149.99
# 18          2899021            close   -5.58       -0.05538    95.18
# 19          1752290            close   -5.20       -0.02840   177.91
# 20           774429            close   -0.94       -0.00976    95.33
# 21          4102946            close    0.08        0.00050   159.80
# 22          1349080            close   -0.27       -0.00732   122.05
# 23          1180825            close    1.11        0.02116    53.56
# 24          1547179            close    0.15        0.00146   102.54
# 25          1577941            close  -20.98       -0.01762  1169.55
# 26          1517832            close  -19.71       -0.01659  1168.39
# 27         10698624            close    0.30        0.00686    44.04
# 28          3660319            close   13.55        0.00763  1789.84
# 29          4597354            close   -0.11       -0.01120     9.71
# ..              ...              ...     ...            ...      ...
# 475         6011500            close   -0.42       -0.01681    24.56
# 476         6730504            close   -1.62       -0.00896   179.20
# 477         1344080            close    0.74        0.01224    61.21
# 478          972903            close    2.62        0.01855   143.87
# 479         2753299            close   -3.40       -0.04913    65.81
# 480         6512738            close    0.38        0.00333   114.64
# 481         4477948            close   -0.76       -0.01485    50.43
# 482         9254584            close   -0.95       -0.00692   136.31
# 483         1718172            close    0.18        0.00151   119.53
# 484          532536            close   -0.30       -0.00142   211.59
# 485         1914264            close    1.96        0.02047    97.73
# 486          445149            close   -1.34       -0.00495   269.40
# 487        19718265            close   -0.48       -0.01031    46.09
# 488         1872897            close    1.82        0.02032    91.38
# 489         4649126            close    0.20        0.00349    57.47
# 490         5304694            close   -0.18       -0.00814    21.94
# 491         2183506            close   -1.17       -0.03423    33.01
# 492         3535004            close    0.09        0.00342    26.40
# 493          735597            close   -4.62       -0.03322   134.47
# 494         9564041            close   -0.05       -0.00212    23.55
# 495          657467            close   -2.31       -0.01167   195.66
# 496         2307151            close   -4.82       -0.04376   105.33
# 497         3427971            close    1.31        0.02040    65.53
# 498         2361495            close    0.12        0.00414    29.11
# 499         3509289            close   -3.66       -0.03517   100.40
# 500          719491            close   -1.97       -0.02571    74.64
# 501         1399361            close   -0.07       -0.00060   116.71
# 502         1332038            close    0.19        0.00136   139.39
# 503         2851524            close   -1.30       -0.03164    39.79
# 504         1872588            close    0.62        0.00490   127.04
#
#          closeTime                                companyName  delayedPrice  \
# 0    1567483200000                                     3M Co.        158.64
# 1    1567483200000                        Abbott Laboratories         84.06
# 2    1567483200000                               AbbVie, Inc.         65.40
# 3    1567483200000                              ABIOMED, Inc.        183.64
# 4    1567483200000                              Accenture Plc        195.75
# 5    1567483200000                  Activision Blizzard, Inc.         51.06
# 6    1567483200000                                Adobe, Inc.        282.45
# 7    1567483200000               Advanced Micro Devices, Inc.         30.90
# 8    1567483200000                   Advance Auto Parts, Inc.        140.36
# 9    1567483200000                              The AES Corp.         15.34
# 10   1567483200000            Affiliated Managers Group, Inc.         74.97
# 11   1567483200000                                Aflac, Inc.         50.38
# 12   1567483200000                 Agilent Technologies, Inc.         70.41
# 13   1567483200000             Air Products & Chemicals, Inc.        225.56
# 14   1567483200000                  Akamai Technologies, Inc.         89.12
# 15   1567483200000                     Alaska Air Group, Inc.         59.84
# 16   1567483200000                            Albemarle Corp.         60.23
# 17   1567483200000      Alexandria Real Estate Equities, Inc.        149.99
# 18   1567483200000              Alexion Pharmaceuticals, Inc.         95.18
# 19   1567483200000                     Align Technology, Inc.        177.91
# 20   1567483200000                               Allegion Plc         95.33
# 21   1567483200000                               Allergan Plc        159.80
# 22   1567483200000                Alliance Data Systems Corp.        122.05
# 23   1567483200000                       Alliant Energy Corp.         53.56
# 24   1567483200000                         The Allstate Corp.        102.54
# 25   1567483200000                             Alphabet, Inc.       1169.55
# 26   1567483200000                             Alphabet, Inc.       1168.39
# 27   1567483200000                         Altria Group, Inc.         44.09
# 28   1567483200000                           Amazon.com, Inc.       1788.50
# 29   1567483200000                                  Amcor Plc          9.71
# ..             ...                                        ...           ...
# 475  1567483200000                               Viacom, Inc.         24.56
# 476  1567483200000                                 Visa, Inc.        179.61
# 477  1567483200000                       Vornado Realty Trust         61.21
# 478  1567483200000                       Vulcan Materials Co.        143.87
# 479  1567483200000  Westinghouse Air Brake Technologies Corp.         65.81
# 480  1567483200000                              Walmart, Inc.        114.58
# 481  1567483200000             Walgreens Boots Alliance, Inc.         50.43
# 482  1567483200000                        The Walt Disney Co.        136.12
# 483  1567483200000                     Waste Management, Inc.        119.53
# 484  1567483200000                               Waters Corp.        211.59
# 485  1567483200000                     WEC Energy Group, Inc.         97.73
# 486  1567483200000                WellCare Health Plans, Inc.        269.40
# 487  1567483200000                          Wells Fargo & Co.         46.09
# 488  1567483200000                            Welltower, Inc.         91.38
# 489  1567483200000                      Western Digital Corp.         57.47
# 490  1567483200000                      The Western Union Co.         21.94
# 491  1567483200000                               WestRock Co.         33.01
# 492  1567483200000                           Weyerhaeuser Co.         26.40
# 493  1567483200000                            Whirlpool Corp.        134.47
# 494  1567483200000                    The Williams Cos., Inc.         23.55
# 495  1567483200000                   Willis Towers Watson Plc        195.66
# 496  1567483200000                          Wynn Resorts Ltd.        105.33
# 497  1567483200000                          Xcel Energy, Inc.         65.53
# 498  1567483200000                       Xerox Holdings Corp.         29.11
# 499  1567483200000                               Xilinx, Inc.        100.40
# 500  1567483200000                                Xylem, Inc.         74.64
# 501  1567483200000                          Yum! Brands, Inc.        116.71
# 502  1567483200000               Zimmer Biomet Holdings, Inc.        139.39
# 503  1567483200000                    Zions Bancorporation NA         39.79
# 504  1567483200000                               Zoetis, Inc.        127.04
#
#      delayedPriceTime  extendedChange  ...       openTime  peRatio  \
# 0       1567541400011            0.00  ...  1567517405225    18.79
# 1       1567541400002            0.00  ...  1567517539113    51.26
# 2       1567541400013            0.10  ...  1567517426522    24.00
# 3       1567540800252            0.36  ...  1567517400755    32.12
# 4       1567541400002            0.00  ...  1567517400485    26.71
# 5       1567540800228            0.33  ...  1567517400700    23.16
# 6       1567540800614            0.43  ...  1567517400873    52.02
# 7       1567541700009            0.04  ...  1567517400511   164.71
# 8       1567541400003            0.00  ...  1567517400419    23.29
# 9       1567541400003            0.00  ...  1567517400433    25.67
# 10      1567541400005            0.00  ...  1567517400416   -32.78
# 11      1567541400004            0.00  ...  1567517400449    12.23
# 12      1567541400002            0.00  ...  1567517403499    20.82
# 13      1567541400002            0.00  ...  1567517400428    29.06
# 14      1567540800477           -0.12  ...  1567517400841    34.41
# 15      1567541400003           -0.32  ...  1567517400438    14.73
# 16      1567541400003            0.40  ...  1567517400468    11.70
# 17      1567541400006            0.00  ...  1567517400410    42.80
# 18      1567540800554            0.00  ...  1567517400300    15.97
# 19      1567540800391           -0.41  ...  1567517400350    34.08
# 20      1567541400012            0.00  ...  1567517400354    20.57
# 21      1567541400000            0.00  ...  1567517400373    -6.25
# 22      1567541400000            0.00  ...  1567517400396     7.53
# 23      1567540800536            0.00  ...  1567517400810    24.77
# 24      1567541400002            0.00  ...  1567517400421    13.21
# 25      1567540800459            1.55  ...  1567517400401    23.39
# 26      1567540800303            0.70  ...  1567517400782    23.37
# 27      1567541400003            0.04  ...  1567517425690    13.07
# 28      1567541700009           -0.42  ...  1567517400650    72.56
# 29      1567541400005            0.00  ...  1567517488374    16.98
# ..                ...             ...  ...            ...      ...
# 475     1567540800452            0.05  ...  1567517400692     6.06
# 476     1567541400009            0.50  ...  1567517402678    34.38
# 477     1567541400001            0.00  ...  1567517400516     4.06
# 478     1567541400001            0.00  ...  1567517419473    33.76
# 479     1567541400001            0.00  ...  1567517400642    36.30
# 480     1567541400000            0.04  ...  1567517400495    25.70
# 481     1567540800264            0.00  ...  1567517400323     9.87
# 482     1567541400008           -0.15  ...  1567517466471    17.10
# 483     1567541400000            0.00  ...  1567517400366    28.90
# 484     1567541400001            0.00  ...  1567517400563    26.69
# 485     1567541400000            0.00  ...  1567517400583    28.16
# 486     1567541400001            0.00  ...  1567517400509    25.63
# 487     1567541400000           -0.11  ...  1567517444768     9.45
# 488     1567541400004           -0.38  ...  1567517400576   101.76
# 489     1567540800247           -0.09  ...  1567517400790   -22.20
# 490     1567541400008            0.00  ...  1567517400355     7.92
# 491     1567541400013            0.00  ...  1567517400527    10.14
# 492     1567541400009           -0.20  ...  1567517400355  5739.13
# 493     1567541400000            0.00  ...  1567517626222     9.39
# 494     1567541400000            0.00  ...  1567517400359   310.28
# 495     1567540800559            0.00  ...  1567517400849    30.04
# 496     1567540800254            0.06  ...  1567517400460    13.63
# 497     1567540800300           -0.03  ...  1567517400706    26.75
# 498     1567541400008            0.00  ...  1567517400358    12.84
# 499     1567540800578            0.00  ...  1567517401031    27.01
# 500     1567541400012            0.00  ...  1567517400394    23.43
# 501     1567541400007            0.00  ...  1567517400354    27.22
# 502     1567541400007            0.00  ...  1567517400369   -79.19
# 503     1567540800768            0.00  ...  1567517400074     9.07
# 504     1567541400013            0.00  ...  1567517400424    44.37
#
#      previousClose  previousVolume          primaryExchange  symbol    volume  \
# 0           161.72         1967010  New York Stock Exchange     MMM   1838159
# 1            85.32         3628594  New York Stock Exchange     ABT   4067856
# 2            65.74         6415479  New York Stock Exchange    ABBV   7935203
# 3           193.07          397103                   NASDAQ    ABMD    647398
# 4           198.17         2176628  New York Stock Exchange     ACN   1699091
# 5            50.60         5891610                   NASDAQ    ATVI   6272025
# 6           284.51         2373297                   NASDAQ    ADBE   1838768
# 7            31.45        40347321                   NASDAQ     AMD  38001364
# 8           137.95          721325  New York Stock Exchange     AAP   1002812
# 9            15.33         5110186  New York Stock Exchange     AES   5745858
# 10           76.63          377886  New York Stock Exchange     AMG    390163
# 11           50.18         3867882  New York Stock Exchange     AFL   3778151
# 12           71.11         2356396  New York Stock Exchange       A   2229118
# 13          225.92          878094  New York Stock Exchange     APD    732226
# 14           89.13         1159643                   NASDAQ    AKAM   1445595
# 15           59.72          842062  New York Stock Exchange     ALK   1111128
# 16           61.73         1404335  New York Stock Exchange     ALB   1372969
# 17          149.84          728618  New York Stock Exchange     ARE    552718
# 18          100.76         8547570                   NASDAQ    ALXN   6286640
# 19          183.11         1679583                   NASDAQ    ALGN   1890515
# 20           96.27          621455  New York Stock Exchange    ALLE    651115
# 21          159.72         1948234  New York Stock Exchange     AGN   4061315
# 22          122.32          709172  New York Stock Exchange     ADS   1475944
# 23           52.45         1592648                   NASDAQ     LNT   2265745
# 24          102.39         2077847  New York Stock Exchange     ALL   1970494
# 25         1190.53          903375                   NASDAQ   GOOGL   1296595
# 26         1188.10         1129959                   NASDAQ    GOOG   1480874
# 27           43.74        13985341  New York Stock Exchange      MO   8941972
# 28         1776.29         3064147                   NASDAQ    AMZN   3543731
# 29            9.82         3963166  New York Stock Exchange    AMCR   3927295
# ..             ...             ...                      ...     ...       ...
# 475          24.98         6138023                   NASDAQ    VIAB   4343760
# 476         180.82         4061275  New York Stock Exchange       V   4656333
# 477          60.47          931014  New York Stock Exchange     VNO    908727
# 478         141.25          914508  New York Stock Exchange     VMC   1186263
# 479          69.21         1020006  New York Stock Exchange     WAB   1737383
# 480         114.26         5706122  New York Stock Exchange     WMT   5953910
# 481          51.19         5194919                   NASDAQ     WBA   3981524
# 482         137.26         5624066  New York Stock Exchange     DIS   6003893
# 483         119.35         1149623  New York Stock Exchange      WM   1207333
# 484         211.89          497192  New York Stock Exchange     WAT    641550
# 485          95.77         1298068  New York Stock Exchange     WEC   2281601
# 486         270.74          210265  New York Stock Exchange     WCG    345231
# 487          46.57        15251816  New York Stock Exchange     WFC  17257428
# 488          89.56         1245503  New York Stock Exchange    WELL   1937304
# 489          57.27         4791316                   NASDAQ     WDC   4520442
# 490          22.12         3435626  New York Stock Exchange      WU   6473395
# 491          34.18         1863604  New York Stock Exchange     WRK   2076052
# 492          26.31         4557895  New York Stock Exchange      WY   2833694
# 493         139.09          556076  New York Stock Exchange     WHR    575011
# 494          23.60         5842845  New York Stock Exchange     WMB   4501529
# 495         197.97          649582                   NASDAQ    WLTW    502714
# 496         110.15         2685571                   NASDAQ    WYNN   2395463
# 497          64.22         3193797                   NASDAQ     XEL   2930915
# 498          28.99         2053639  New York Stock Exchange     XRX   2433023
# 499         104.06         1938788                   NASDAQ    XLNX   3218488
# 500          76.61          637587  New York Stock Exchange     XYL    709474
# 501         116.78         1154468  New York Stock Exchange     YUM   1365339
# 502         139.20         1025677  New York Stock Exchange     ZBH    873249
# 503          41.09         1490782                   NASDAQ    ZION   2581419
# 504         126.42         1601187  New York Stock Exchange     ZTS   1891376
#
#      week52High  week52Low  ytdChange
# 0        219.75     154.00  -0.172127
# 1         88.76      65.22   0.212856
# 2         96.60      62.66  -0.268422
# 3        459.75     181.02  -0.425953
# 4        200.68     132.63   0.397350
# 5         84.67      39.85   0.084999
# 6        313.11     204.95   0.259670
# 7         35.55      16.03   0.652717
# 8        186.15     130.09  -0.108986
# 9         18.52      13.00   0.081750
# 10       147.94      73.90  -0.241552
# 11        57.18      41.44   0.106363
# 12        82.27      61.01   0.072669
# 13       232.46     148.44   0.414038
# 14        90.76      57.18   0.510312
# 15        74.83      53.38  -0.017369
# 16       108.74      58.63  -0.234004
# 17       153.51     109.04   0.346425
# 18       141.86      92.56  -0.027741
# 19       398.87     172.11  -0.122453
# 20       111.99      74.83   0.178025
# 21       197.00     114.27   0.175949
# 22       250.27     120.77  -0.216034
# 23        53.56      40.68   0.295765
# 24       109.13      77.00   0.255625
# 25      1296.97     977.65   0.111187
# 26      1289.27     970.11   0.119424
# 27        66.04      42.40  -0.106099
# 28      2050.50    1307.00   0.161717
# 29        11.77       9.32  -0.132846
# ..          ...        ...        ...
# 475       34.44      23.31  -0.082978
# 476      184.07     121.60   0.351407
# 477       77.14      58.60   0.014062
# 478      144.23      82.52   0.465932
# 479      115.40      61.00  -0.072415
# 480      115.49      85.78   0.227457
# 481       86.31      49.03  -0.262498
# 482      147.15     100.35   0.252693
# 483      120.58      83.22   0.346753
# 484      255.21     167.93   0.153861
# 485       97.73      64.96   0.437605
# 486      324.99     220.63   0.156725
# 487       59.19      43.02  -0.018192
# 488       91.38      60.93   0.351276
# 489       61.75      33.83   0.500354
# 490       22.32      16.42   0.282408
# 491       57.23      31.94  -0.155341
# 492       34.80      20.52   0.225436
# 493      152.50      99.40   0.255605
# 494       29.65      20.36   0.050512
# 495      200.93     134.50   0.310952
# 496      151.50      90.06   0.011317
# 497       65.53      46.01   0.352213
# 498       36.57      18.57   0.444279
# 499      141.60      68.76   0.162988
# 500       85.39      60.65   0.126147
# 501      119.72      84.53   0.276522
# 502      140.53      96.99   0.362330
# 503       54.37      38.08  -0.043425
# 504      128.41      78.90   0.501349
#
# [505 rows x 43 columns]

# %%
# Windows Users - Executable Path
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# # Moving dataframe to HTML
# stock_table_df = pd.DataFrame(stock_table)

# stock_table_df[0]

# # # Saving the file to HTML
# # fact_table_df.to_html('mars_fact_table.html')
